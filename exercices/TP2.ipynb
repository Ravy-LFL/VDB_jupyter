# %% [markdown]
# ## Objectifs
# ##### 1 Lire et traiter des données d'entrée avec [PANDAS](https://pandas.pydata.org/)
#
# ##### 2 Représenter la distribution empirique des "fold-change" (**FC**) vs Précision, aka: volcano-plot
#
# ##### 3 Effectuer une analyse de sur-représentation en termes GO
#
#
# ## Ressources : Rappels et illustration de l'analyse de représentation de termes GO
# ###### [TP de MADP](https://github.com/glaunay/tp-proteomics#3-obtention-des-param%C3%A8tres-du-mod%C3%A8le)
# ###### [Fiche Bioconductor](https://www.bioconductor.org/help/course-materials/2015/SeattleApr2015/E_GeneSetEnrichment.html)

# %% [markdown]
# ### Préparation de  l'environnement
#
# ##### Please `pip install -r requirements.txt` first
#
# ##### Directory Configuration
#
# * `workDir` points to the Git project, holds the *tsv* file
# * `libDir` points to Git project subdirectory hosting python library with files names `go.py  stat_utils.py  uniprot.py`
# * `dataDir` points to the data folder with uniprot and GO files

# %%
import sys, os
workDir = f"{os.getcwd()}/.."
libDir = f"{workDir}/lib"
dataDir= f"{workDir}/data" 

sys.path.append(libDir)

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas
import numpy as np

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# %% [markdown]
# ## Jeux de données
# * Jeux de données de protéomique quantitative au format TSV
# * Ontologie GO au format [owl](http://www.obofoundry.org/ontology/go.html)
# * Entrées Uniprot au format XML
#     * Protéines de l'étude
#     * Protéome d'E.Coli complet
#
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# ### Lecture des valeurs experimentales
# Charger ```TCL_wt1.tsv``` dans une [dataframe pandas](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html).
# <br/><span style="color:firebrick;font-weight:bold"> $\rhd$
# Retirer les lignes présentant des aberrations numériques
# </span>
# <br/><span style="color:firebrick;font-weight:bold">$\rhd$ Attention aux types des colonnes !</span>

# %%
df = pandas.read_csv("../TCL_wt1.tsv",sep="\t",na_values="#VALEUR!", dtype={"Log2 Corrected Abundance Ratio":"float"})
data_frame = df.dropna()
data_frame
# Out:
#      Accession                                        Description Gene Symbol  \
# 0       P75936  Basal-body rod modification protein FlgD OS=Es...        flgD
# 1       P76231  Uncharacterized protein YeaC OS=Escherichia co...        yeaC
# 2       P0A8S9  Flagellar transcriptional regulator FlhD OS=Es...        flhD
# 4       P05706  PTS system glucitol/sorbitol-specific EIIA com...        srlB
# 5       P29744  Flagellar hook-associated protein 3 OS=Escheri...        flgL
# ...        ...                                                ...         ...
# 2011    P77330  Prophage lipoprotein Bor homolog OS=Escherichi...        borD
# 2016    P02930  Outer membrane protein TolC OS=Escherichia col...        tolC
# 2020    P0A917  Outer membrane protein X OS=Escherichia coli (...        ompX
# 2021    P02931  Outer membrane protein F OS=Escherichia coli (...        ompF
# 2022    P0AB40  Multiple stress resistance protein BhsA OS=Esc...        bhsA
#
#       Corrected Abundance ratio (1.53)  Log2 Corrected Abundance Ratio  \
# 0                             0.075817                       -3.721335
# 1                             0.092810                       -3.429569
# 2                             0.102614                       -3.284695
# 4                             0.108497                       -3.204277
# 5                             0.124183                       -3.009460
# ...                                ...                             ...
# 2011                          1.535948                        0.619129
# 2016                          1.552288                        0.634396
# 2020                          1.579739                        0.659686
# 2021                          1.754902                        0.811390
# 2022                          1.798039                        0.846424
#
#       Abundance Ratio Adj. P-Value: (127. T3 Tc WT) / (126. T0 WT)  \
# 0                                              0.000055
# 1                                              0.000351
# 2                                              0.000027
# 4                                              0.019963
# 5                                              0.036746
# ...                                                 ...
# 2011                                           0.310725
# 2016                                           0.013373
# 2020                                           0.002226
# 2021                                           0.000068
# 2022                                           0.035928
#
#       LOG10 Adj.P-val
# 0            4.260067
# 1            3.454627
# 2            4.571899
# 4            1.699768
# 5            1.434787
# ...               ...
# 2011         0.507623
# 2016         1.873757
# 2020         2.652391
# 2021         4.164956
# 2022         1.444561
#
# [1746 rows x 7 columns]

# %% [markdown]
# ##### 1. Un premier volcano-plot
#
# Ce type de figure représente pour chaque protéine en abscisse le taux d'abondance et en ordonnée la précision de la mesure.
#
# <span style="color:firebrick;font-weight:bold">$\rhd$ 1. Réaliser un scatter plot matplotlib avec</span>
# <br/><span style="color:firebrick;font-weight:bold">- en x, `Log2 Corrected Abundance Ratio`</span>
# <br/><span style="color:firebrick;font-weight:bold">-  en y, `LOG10 Adj.P-val`</span>
#
# <span style="color:firebrick;font-weight:bold">$\rhd$Vous légenderez les axes, attention `LOG10 Adj.P-val` est en fait `-LOG10 Adj.P-val`, regardez bien.</span>

# %% [markdown]
# ##### 2. Réaliser des versions évoluées du graphique précédent
# L'objectif est de mettre l'accent sur la région **-Log10 adj Pvalue > 4** et **Log2 corrected abundance ratio > 0**.
# <br/>Pour cela vous revisiterez le scatter plot précedent au travers des versions suivantes:
# <br/><span style="color:firebrick;font-weight:bold"> $\rhd$ première version : un rectangle de la couleur de votre choix matérialisera la région</span>
# <br/><span style="color:firebrick;font-weight:bold"> $\rhd$ deuxième version  : une couleur de votre choix représentera les points de la région</span>
# <br/><span style="color:firebrick;font-weight:bold"> $\rhd$ troisème version (optionnel): Les identifiants uniprot remplaceront les points des protéines de la région</span>

# %%
df2 = data_frame[(data_frame["Log2 Corrected Abundance Ratio"]>0) & (data_frame["LOG10 Adj.P-val"]>4)]
dico_annot = {}
for index, row in df2.iterrows():
    cle = row["Accession"]
    x = row["Log2 Corrected Abundance Ratio"]
    y = row["LOG10 Adj.P-val"]
    dico_annot[cle]=(x,y)

# %%
RETINA = 226
x = pandas.to_numeric(data_frame["Log2 Corrected Abundance Ratio"])
y = pandas.to_numeric(data_frame["LOG10 Adj.P-val"])
col = np.where(x<0,'g',np.where(y<4,'g','b'))
fig, ax = plt.subplots(dpi=RETINA)
ax.scatter(x,y,c=col)
ax.set_xlabel("Log2 Corrected Abundance Ratio")
ax.set_ylabel("LOG10 Adj.P-val")
rect = patches.Rectangle((0, 4), 1, 3, linewidth=1, edgecolor='r', facecolor='none')
ax.add_patch(rect)
for i in dico_annot.keys():
    ax.text(dico_annot[i][0],dico_annot[i][1],i,fontsize=5)

# %% [markdown]
# #### Analyse ORA
#
# ##### Principes
# Vous disposez d'un objet analyser permettant de réaliser une analyse de la sur-représentation (**ORA**) en termes GO parmi une liste de protéine d'intérêt.
# La fréquence des termes GO dans le protéome totale est utilisée comme référence.
#
# L'objet analyser s'instancie ainsi
# ```python
# from stat_utils import GO_ORA_analyser
# o = GO_ORA_analyser(f"{dataDir}/go.owl", f"{dataDir}/K12_proteome", f"{dataDir}/dataset")
# ```
#
# Il fournit une méthode pour chaque catégorie de termes GO
# <i>{ biological_process, molecular_function, cellular_component }</i>
#
# Une éventuelle surreprésentation des termes GO de la catégorie <i>biological_process</i> est par exemple calculée parmi les protéines P29744 et P05706 de la façon suivante:
#
# ```python
# goTerm_scores = o.biological_process(["P29744", "P05706"])
# ```
# <span style="color:green;font-weight:bold">$\uparrow$ Reproduire cet exemple dans la cellule ci-dessous.$\downarrow$ </span>
# </br><span style="color:firebrick;font-weight:bold"> $\rhd$ Inspecter l'objet retourné par la méthode o.biological_process, que voyez-vous ?</span>

# %%
from stat_utils import GO_ORA_analyser
o = GO_ORA_analyser(f"{dataDir}/go.owl", f"{dataDir}/K12_proteome", f"{dataDir}/dataset")
# Out:
# Loading ontology
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/owlready2/driver.py:149, in BaseSubGraph.parse(self, f, format, delete_existing_triples, default_base)
#     147 bn_src_2_sql = {}
# --> 149 line = f.readline().decode("utf8")
#     150 while line:
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xba in position 37: invalid start byte
#
# The above exception was the direct cause of the following exception:
#
# OwlReadyOntologyParsingError              Traceback (most recent call last)
# Input In [17], in <cell line: 2>()
#       1 from stat_utils import GO_ORA_analyser
# ----> 2 o = GO_ORA_analyser(f"{dataDir}/go.owl", f"{dataDir}/K12_proteome", f"{dataDir}/dataset")
#
# File ~/vdb/VDB_jupyter/exercices/../lib/stat_utils.py:11, in GO_ORA_analyser.__init__(self, goOntologyFile, proteomeDirectory, experimentalProteinDirectory)
#       9 def __init__(self, goOntologyFile, proteomeDirectory, experimentalProteinDirectory):
#      10     print("Loading ontology")
# ---> 11     go.setOntology(goOntologyFile)
#      12     print("Reading whole proteome")
#      13     self.proteomeCollection = uniprot.UniprotCollection(proteomeDirectory)
#
# File ~/vdb/VDB_jupyter/exercices/../lib/go.py:9, in setOntology(file)
#       7 def setOntology(file):
#       8     global GO_ONTOLOGY
# ----> 9     GO_ONTOLOGY = OntologyGO(file)
#
# File ~/vdb/VDB_jupyter/exercices/../lib/go.py:51, in OntologyGO.__init__(self, owlFile)
#      50 def __init__(self, owlFile):
# ---> 51     self.onto = ontology.Ontology(file=owlFile)
#      52     print('Loaded')
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pyproteinsExt/ontology.py:26, in Ontology.__init__(self, file)
#      23 def __init__(self, file=None):
#      24     #super(Ontology, self).__init__(ressource)
#      25     if file:
# ---> 26         self.onto = get_ontology("file://" + file).load()
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/owlready2/namespace.py:1058, in Ontology.load(self, only_local, fileobj, reload, reload_if_newer, url, **args)
#    1056   if _LOG_LEVEL: print("* Owlready2 *     ...loading ontology %s from %s..." % (self.name, f), file = sys.stderr)
#    1057   fileobj = open(f, "rb")
# -> 1058   try:     new_base_iri = self.graph.parse(fileobj, default_base = self._base_iri, **args)
#    1059   finally: fileobj.close()
#    1060 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/owlready2/driver.py:190, in BaseSubGraph.parse(self, f, format, delete_existing_triples, default_base)
#     188       raise OwlReadyOntologyParsingError("NTriples parsing error (or unrecognized file format) in %s, line %s." % (getattr(f, "name", getattr(f, "url", "???")), current_line)) from e
#     189     else:
# --> 190       raise OwlReadyOntologyParsingError("NTriples parsing error (or unrecognized file format) in %s." % getattr(f, "name", getattr(f, "url", "???"))) from e
#     192 elif format == "rdfxml":
#     193   objs, datas, on_prepare_obj, on_prepare_data, insert_objs, insert_datas, new_blank, _abbreviate, on_finish = self.create_parse_func(getattr(f, "name", ""), delete_existing_triples)
#
# OwlReadyOntologyParsingError: NTriples parsing error (or unrecognized file format) in /Users/ravy/vdb/VDB_jupyter/exercices/../data/go.owl.

# %%
o.biological_process
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 o.biological_process
#
# NameError: name 'o' is not defined

# %%
o.proteomeCollection

# %%
help(o)
# Out:
# Help on GO_ORA_analyser in module stat_utils object:
#
# class GO_ORA_analyser(builtins.object)
#  |  GO_ORA_analyser(goOntologyFile, proteomeDirectory, experimentalProteinDirectory)
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, goOntologyFile, proteomeDirectory, experimentalProteinDirectory)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  biological_process(self, selectedUniprotList)
#  |
#  |  cellular_component(self, selectedUniprotList)
#  |
#  |  molecular_function(self, selectedUniprotList)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %% [markdown]
# ###### 2/ Analyser la représentation des termes GO parmi les protéines surabondantes de l'experience
# <span style="color:firebrick;font-weight:bold"> $\rhd$ Vous devrez extraire les identifiants uniprot des protéines aux `Log2 Corrected Abundance Ratio` supérieurs au seuil alpha de 5%.</span>
# <br/><span style="color:firebrick;font-weight:bold"> $\rhd$ Vous conduirez sur cette liste de protéines une analyse de sur-représentation en termes GO à l'aide d'un objet *GO_ORA_analyser*.</span>
# <br/><span style="color:firebrick;font-weight:bold"> $\rhd$ Vous pouvez faire varier le seuil d'abondance autour de la valeur alpha.</span>
# <br/><span style="color:firebrick;font-weight:bold"> $\rhd$ Vous traiterez les 3 catégories *biological_process / molecular_function /cellular_component*.</span>
#
#
#
# Familiarisez-vous avec la structures des dictionnaires de résultas, vous pouvez [les sauvegarder au format json](https://docs.python.org/3/library/json.html).

# %%
list_id_sup_5 = list(data_frame[(data_frame["Log2 Corrected Abundance Ratio"]>0.05)]["Accession"])
list_id_sup_5 #Liste contenant les id des prot superieur au seuil de 5%
bp_sup5=o.biological_process(list_id_sup_5)
mc_sup5=o.cellular_component(list_id_sup_5)
mf_sup5=o.molecular_function(list_id_sup_5)
# Out:
# Building biological process GO Tree
# Extracting biological process ontology
# Applying true path collapsing
# 247 GO terms, 62 leaves, 27 proteins
# Extracting biological process ontology
# Applying true path collapsing
# 2728 GO terms, 6650 leaves, 3128 proteins
# Evaluated 246 / 246 Pathways, based on 37 proteins
# cellular component process GO Tree
# Extracting cellular component ontology
# Applying true path collapsing
# 51 GO terms, 78 leaves, 36 proteins
# Extracting cellular component ontology
# Applying true path collapsing
# 239 GO terms, 4698 leaves, 2805 proteins
# Evaluated 50 / 50 Pathways, based on 37 proteins
# molecular function process GO Tree
# Extracting molecular function ontology
# Applying true path collapsing
# 81 GO terms, 74 leaves, 23 proteins
# Extracting molecular function ontology
# Applying true path collapsing
# 2264 GO terms, 7807 leaves, 3118 proteins
# Evaluated 80 / 80 Pathways, based on 37 proteins

# %%
seuil = 0.03
while seuil != 0.1 :
    print(f" voici le nouveau seuil {seuil} : \n")
    list_id_sup_seuil = list(data_frame[(data_frame["Log2 Corrected Abundance Ratio"]>seuil)]["Accession"])
    print(o.biological_process(list_id_sup_seuil))
    print(o.cellular_component(list_id_sup_seuil))
    print(o.molecular_function(list_id_sup_seuil))
    print("------------------------------------------------------------------- \n")
    seuil += 0.01
# Out:
#  voici le nouveau seuil 0.03 :
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [10], in <cell line: 2>()
#       3 print(f" voici le nouveau seuil {seuil} : \n")
#       4 list_id_sup_seuil = list(data_frame[(data_frame["Log2 Corrected Abundance Ratio"]>seuil)]["Accession"])
# ----> 5 print(o.biological_process(list_id_sup_seuil))
#       6 print(o.cellular_component(list_id_sup_seuil))
#       7 print(o.molecular_function(list_id_sup_seuil))
#
# File ~/vdb/VDB_jupyter/exercices/../lib/stat_utils.py:39, in GO_ORA_analyser.biological_process(self, selectedUniprotList)
#      34     _ = self.proteomeCollection.list
#      35     self._bk_BP = go.createGoTree(ns=ns,
#      36                                   proteinList=_,
#      37                                   uniprotCollection=self.proteomeCollection
#      38     )
# ---> 39 Fisher_ORA = self._compute_ora(ns, self._xp_BP, self._bk_BP, selectedUniprotList)
#      40 return sorted(
#      41     [ (pValue, cPath.name, cPath.ID, cPath.getMembers() ) for pValue, cPath in Fisher_ORA ],
#      42     key=lambda e:e[0]
#      43 )
#
# File ~/vdb/VDB_jupyter/exercices/../lib/stat_utils.py:103, in GO_ORA_analyser._compute_ora(self, ns, tree_xp, tree_bk, selectedProteinList)
#      99     pathWayBKG = tree_bk.getByName(ns)
#     100 #    print(pathWayRoot)
#     101 #    print(pathWayBKG)
#     102     #Calcul de l'enrichissement en termes GO successifs parmi les protéines surabondantes (ici, saList)
# --> 103     oraScores = computeORA(pathWayRoot, selectedProteinList, pathWayBKG)
#     105     return oraScores
#
# File ~/vdb/VDB_jupyter/exercices/../lib/stat_utils.py:155, in computeORA(node, proteinList, nodeBKG, verbose)
#     154 def computeORA(node, proteinList, nodeBKG, verbose=False):
# --> 155     Fisher, CDF = computeORA_BKG(node, proteinList, nodeBKG, verbose=verbose)
#     156     return Fisher
#
# File ~/vdb/VDB_jupyter/exercices/../lib/stat_utils.py:200, in computeORA_BKG(node, proteinList, nodeBKG, verbose)
#     197 pathwayReal += 1
#     198 # Pour estimer le nombre de protéines non surAbondantes appartenant au pathway ou non
#     199 # Nous utilisons la proporition de protéines du pathway ou non dans le protéome entier
# --> 200 bkgPath = nodeBKG.getByName(cPath.name)
#     201 if not bkgPath:
#     202     continue
#
# File ~/vdb/VDB_jupyter/exercices/../lib/go.py:257, in Node.getByName(self, name)
#     255     return self
#     256 for c in self.children:
# --> 257     v = c.getByName(name)
#     258     if v:
#     259         return v
#
# File ~/vdb/VDB_jupyter/exercices/../lib/go.py:257, in Node.getByName(self, name)
#     255     return self
#     256 for c in self.children:
# --> 257     v = c.getByName(name)
#     258     if v:
#     259         return v
#
# File ~/vdb/VDB_jupyter/exercices/../lib/go.py:257, in Node.getByName(self, name)
#     255     return self
#     256 for c in self.children:
# --> 257     v = c.getByName(name)
#     258     if v:
#     259         return v
#
# File ~/vdb/VDB_jupyter/exercices/../lib/go.py:254, in Node.getByName(self, name)
#     252 regExp = name.replace(' ', '.').replace('[', '.').replace(']', '.').replace('_', '.').replace(')', '\)').replace('(', '\(')
#     253 regExp = regExp.replace('+', '.')
# --> 254 if re.search("^" + regExp + "$", self.name):
#     255     return self
#     256 for c in self.children:
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/re.py:201, in search(pattern, string, flags)
#     198 def search(pattern, string, flags=0):
#     199     """Scan through string looking for a match to the pattern, returning
#     200     a Match object, or None if no match was found."""
# --> 201     return _compile(pattern, flags).search(string)
#
# KeyboardInterrupt:

# %%
print(f"biological process : {bp_sup5[0]} \ncellular component : {mc_sup5[0]} \nmolecular_function : {mf_sup5[0]}")
# Out:
# biological process : (1.277774972034038e-06, 'siderophore transport', 'GO:0015891', ['P13036', 'P06971', 'P75780', 'P02930', 'P05825'])
# cellular component : (6.744103642899227e-22, 'external encapsulating structure part', 'GO:0044462', ['P77774', 'P0A940', 'P0A937', 'P09169', 'P05825', 'P0A937', 'P06996', 'P0A940', 'P09169', 'P05825', 'P0A915', 'P39180', 'P0A905', 'P76471', 'P76506', 'P13036', 'P0A927', 'P10384', 'P06971', 'P0A910', 'P0A908', 'P75780', 'P06996', 'P06129', 'P02930', 'P0A917', 'P02931', 'P0AB40'])
# molecular_function : (1.7979035567056582e-07, 'channel activity', 'GO:0015267', ['P05825', 'P10384', 'P0A910', 'P06996', 'P06129', 'P02930', 'P02931', 'P0A927', 'P10384', 'P06129', 'P02930', 'P02931'])

# %%
bp_sup5
# Out:
# [(1.277774972034038e-06,
#   'siderophore transport',
#   'GO:0015891',
#   ['P13036', 'P06971', 'P75780', 'P02930', 'P05825']),
#  (6.023913047836394e-06,
#   'iron coordination entity transport',
#   'GO:1901678',
#   ['P05825', 'P05825', 'P13036', 'P06971', 'P75780', 'P02930']),
#  (5.532051927766727e-05,
#   'iron ion transport',
#   'GO:0006826',
#   ['P13036', 'P05825', 'P05825', 'P13036', 'P06971', 'P75780', 'P02930']),
#  (0.0001270732486959893,
#   'ion transport',
#   'GO:0006811',
#   ['P0A927',
#    'P0A910',
#    'P13036',
#    'P05825',
#    'P05825',
#    'P13036',
#    'P06971',
#    'P75780',
#    'P02930',
#    'P0AER8',
#    'P06996',
#    'P76506',
#    'P0A910',
#    'P06129',
#    'P02930',
#    'P02931']),
#  (0.00023017691092962867,
#   'membrane organization',
#   'GO:0061024',
#   ['P77774', 'P0A940', 'P0A937', 'P77774', 'P0A940', 'P0A937', 'P76506']),
#  (0.00038932504762125263,
#   'protein insertion into membrane',
#   'GO:0051205',
#   ['P77774', 'P0A940', 'P0A937']),
#  (0.0006094525728954648,
#   'Gram-negative-bacterium-type cell outer membrane assembly',
#   'GO:0043165',
#   ['P77774', 'P0A940', 'P0A937']),
#  (0.0006094525728954648,
#   'membrane assembly',
#   'GO:0071709',
#   ['P77774', 'P0A940', 'P0A937']),
#  (0.0007440622520732061,
#   'establishment of protein localization to membrane',
#   'GO:0090150',
#   ['P77774', 'P0A940', 'P0A937']),
#  (0.0009756392518373065,
#   'iron ion homeostasis',
#   'GO:0055072',
#   ['P13036', 'P06971', 'P75780', 'P05825', 'P05825']),
#  (0.0013025572322994698,
#   'phospholipid transport',
#   'GO:0015914',
#   ['P06996', 'P76506']),
#  (0.001825589084162934,
#   'transition metal ion homeostasis',
#   'GO:0055076',
#   ['P05825', 'P05825', 'P13036', 'P06971', 'P75780']),
#  (0.0019788009948913735,
#   'metal ion homeostasis',
#   'GO:0055065',
#   ['P05825', 'P05825', 'P13036', 'P06971', 'P75780']),
#  (0.002135325180678235,
#   'establishment of localization',
#   'GO:0051234',
#   ['P77774',
#    'P0A940',
#    'P0A937',
#    'P05825',
#    'P75780',
#    'P0AER8',
#    'P0A927',
#    'P06129',
#    'P02930',
#    'P05825',
#    'P06996',
#    'P76506',
#    'P0A927',
#    'P0A910',
#    'P13036',
#    'P05825',
#    'P13036',
#    'P06971',
#    'P75780',
#    'P0A910',
#    'P06129',
#    'P02930',
#    'P02931',
#    'P02931',
#    'P02930']),
#  (0.0024917150479736015,
#   'cellular localization',
#   'GO:0051641',
#   ['P77774', 'P0A940', 'P0A937', 'P05825', 'P05825']),
#  (0.002842060716026531,
#   'cofactor transport',
#   'GO:0051181',
#   ['P02930', 'P05825', 'P06129']),
#  (0.003779643414969773,
#   'cation homeostasis',
#   'GO:0055080',
#   ['P05825', 'P05825', 'P13036', 'P06971', 'P75780']),
#  (0.004031108403003663,
#   'ion homeostasis',
#   'GO:0050801',
#   ['P05825', 'P05825', 'P13036', 'P06971', 'P75780']),
#  (0.00455270063425091,
#   'enterobactin transport',
#   'GO:0042930',
#   ['P02930', 'P05825']),
#  (0.004819061440716164,
#   'cellular protein localization',
#   'GO:0034613',
#   ['P77774', 'P0A940', 'P0A937']),
#  (0.004819061440716164,
#   'cellular macromolecule localization',
#   'GO:0070727',
#   ['P77774', 'P0A940', 'P0A937']),
#  (0.004853313854698309,
#   'chemical homeostasis',
#   'GO:0048878',
#   ['P05825', 'P05825', 'P13036', 'P06971', 'P75780']),
#  (0.005098199016710273,
#   'localization',
#   'GO:0051179',
#   ['P77774',
#    'P0A940',
#    'P0A937',
#    'P06996',
#    'P76506',
#    'P05825',
#    'P75780',
#    'P0AER8',
#    'P0A927',
#    'P06129',
#    'P02930',
#    'P05825',
#    'P0A927',
#    'P0A910',
#    'P13036',
#    'P05825',
#    'P13036',
#    'P06971',
#    'P75780',
#    'P0A910',
#    'P06129',
#    'P02930',
#    'P02931',
#    'P02931',
#    'P02930']),
#  (0.00758232913911829,
#   'drug transport',
#   'GO:0015893',
#   ['P02931', 'P0AER8', 'P06129', 'P02930']),
#  (0.01109230073813465,
#   'viral entry into host cell',
#   'GO:0046718',
#   ['P0A927', 'P0A910']),
#  (0.011694058154235146,
#   'co-translational protein modification',
#   'GO:0043686',
#   ['P0A6K3']),
#  (0.011694058154235146, 'detection of virus', 'GO:0009597', ['P0A910']),
#  (0.012785797566823636,
#   'macromolecule localization',
#   'GO:0033036',
#   ['P77774', 'P0A940', 'P0A937', 'P06996', 'P76506']),
#  (0.013215086461965446,
#   'ion transmembrane transport',
#   'GO:0034220',
#   ['P0A910', 'P06129', 'P02930', 'P02931', 'P0AER8']),
#  (0.015101071813365109,
#   'homeostatic process',
#   'GO:0042592',
#   ['P05825', 'P05825', 'P13036', 'P06971', 'P75780']),
#  (0.01777216828190163,
#   'response to metal ion',
#   'GO:0010038',
#   ['P76344', 'P77330', 'P0AB40']),
#  (0.019718028893727195,
#   'organic anion transport',
#   'GO:0015711',
#   ['P02930', 'P05825', 'P0AER8', 'P06996', 'P76506']),
#  (0.022162914789973308, 'lipid transport', 'GO:0006869', ['P06996', 'P76506']),
#  (0.022554827580056305,
#   'response to chemical',
#   'GO:0042221',
#   ['P0ADB7',
#    'P0A937',
#    'P02930',
#    'P02931',
#    'P0AER8',
#    'P06129',
#    'P02930',
#    'P76344',
#    'P77330',
#    'P0AB40',
#    'P02930']),
#  (0.02325501921913976,
#   'intermembrane phospholipid transfer',
#   'GO:0120010',
#   ['P76506']),
#  (0.02325501921913976,
#   'cellular response to zinc ion starvation',
#   'GO:0034224',
#   ['P76344']),
#  (0.02325501921913976,
#   'cellular response to magnesium ion',
#   'GO:0071286',
#   ['P77330']),
#  (0.02325501921913976, 'colicin transport', 'GO:0042914', ['P05825']),
#  (0.028871685432643505,
#   'interaction with host',
#   'GO:0051701',
#   ['P0A927', 'P0A910']),
#  (0.03258358726458561,
#   'anion transport',
#   'GO:0006820',
#   ['P02930', 'P05825', 'P0AER8', 'P06996', 'P76506']),
#  (0.033537505530004855,
#   'transport',
#   'GO:0006810',
#   ['P05825',
#    'P75780',
#    'P0AER8',
#    'P0A927',
#    'P06129',
#    'P02930',
#    'P05825',
#    'P06996',
#    'P76506',
#    'P0A927',
#    'P0A910',
#    'P13036',
#    'P05825',
#    'P13036',
#    'P06971',
#    'P75780',
#    'P0A910',
#    'P06129',
#    'P02930',
#    'P02931',
#    'P02931',
#    'P02930']),
#  (0.03468435643890315,
#   'L-proline biosynthetic process',
#   'GO:0055129',
#   ['P0A9L8']),
#  (0.03468435643890315, 'maturation of SSU-rRNA', 'GO:0030490', ['P0A7G2']),
#  (0.03468435643890315, 'conjugation', 'GO:0000746', ['P0A910']),
#  (0.03468435643890315,
#   'L-glutamate transmembrane transport',
#   'GO:0015813',
#   ['P0AER8']),
#  (0.03468435643890315,
#   'response to organic cyclic compound',
#   'GO:0014070',
#   ['P02930']),
#  (0.045983527211367746,
#   'proline biosynthetic process',
#   'GO:0006561',
#   ['P0A9L8']),
#  (0.045983527211367746, 'proline metabolic process', 'GO:0006560', ['P0A9L8']),
#  (0.045983527211367746,
#   'negative regulation of single-species biofilm formation on inanimate substrate',
#   'GO:1900232',
#   ['P0ACF8']),
#  (0.045983527211367746,
#   'intermembrane lipid transfer',
#   'GO:0120009',
#   ['P76506']),
#  (0.045983527211367746, 'drug export', 'GO:0046618', ['P02930']),
#  (0.045983527211367746, 'response to cadmium ion', 'GO:0046686', ['P76344']),
#  (0.05006324988424036,
#   'symbiotic process',
#   'GO:0044403',
#   ['P0A927', 'P0A910']),
#  (0.057153973253513124,
#   'N-terminal protein amino acid modification',
#   'GO:0031365',
#   ['P0A6K3']),
#  (0.057153973253513124,
#   'negative regulation of single-species biofilm formation',
#   'GO:1900191',
#   ['P0ACF8']),
#  (0.057153973253513124, 'cobalamin transport', 'GO:0015889', ['P06129']),
#  (0.057153973253513124,
#   'negative regulation of multi-organism process',
#   'GO:0043901',
#   ['P0ACF8']),
#  (0.06541576469927579,
#   'interspecies interaction between organisms',
#   'GO:0044419',
#   ['P0A927', 'P0A910']),
#  (0.0681971207652637,
#   'ferric-enterobactin import into cell',
#   'GO:0015685',
#   ['P05825']),
#  (0.0681971207652637, 'nucleoside transport', 'GO:0015858', ['P0A927']),
#  (0.06948027078084751,
#   'response to inorganic substance',
#   'GO:0010035',
#   ['P76344', 'P77330', 'P0AB40']),
#  (0.07706624637920949,
#   'cellular component biogenesis',
#   'GO:0044085',
#   ['P77774', 'P0A940', 'P0A937', 'P62399', 'P02931', 'P0A7G2', 'P0A908']),
#  (0.07911438059163647, 'protein homotrimerization', 'GO:0070207', ['P02931']),
#  (0.07911438059163647,
#   'regulation of single-species biofilm formation on inanimate substrate',
#   'GO:1900231',
#   ['P0ACF8']),
#  (0.07911438059163647, 'microcin transport', 'GO:0042884', ['P75780']),
#  (0.08027757662824633,
#   'translation',
#   'GO:0006412',
#   ['P0A6K3', 'P0A7K2', 'P62399', 'P0ACF8']),
#  (0.08423347914867976,
#   'organic substance transport',
#   'GO:0071702',
#   ['P05825',
#    'P75780',
#    'P02930',
#    'P05825',
#    'P0AER8',
#    'P06996',
#    'P76506',
#    'P0A927',
#    'P06129']),
#  (0.09272646695575094,
#   'drug transmembrane transport',
#   'GO:0006855',
#   ['P02931', 'P0AER8']),
#  (0.09569991493111658,
#   'establishment of protein localization',
#   'GO:0045184',
#   ['P77774', 'P0A940', 'P0A937']),
#  (0.09804917169904069,
#   'protein localization',
#   'GO:0008104',
#   ['P77774', 'P0A940', 'P0A937']),
#  (0.10057680475517819,
#   'siderophore-dependent iron import into cell',
#   'GO:0033214',
#   ['P05825', 'P05825']),
#  (0.10121118644051987,
#   'peptide biosynthetic process',
#   'GO:0043043',
#   ['P0A6K3', 'P0A7K2', 'P62399', 'P0ACF8']),
#  (0.11112471544426171,
#   'nucleobase-containing compound transport',
#   'GO:0015931',
#   ['P0A927']),
#  (0.12650723587630439,
#   'peptide metabolic process',
#   'GO:0006518',
#   ['P0A6K3', 'P0A7K2', 'P62399', 'P0ACF8']),
#  (0.13083265531786187,
#   'cellular component assembly',
#   'GO:0022607',
#   ['P77774', 'P0A940', 'P0A937', 'P62399', 'P02931']),
#  (0.14517621926894583,
#   'nitrogen compound transport',
#   'GO:0071705',
#   ['P05825', 'P75780', 'P0AER8', 'P0A927', 'P06129']),
#  (0.15212570404290615,
#   'regulation of single-species biofilm formation',
#   'GO:1900190',
#   ['P0ACF8']),
#  (0.15212570404290615,
#   'regulation of multi-organism process',
#   'GO:0043900',
#   ['P0ACF8']),
#  (0.15877553680823658,
#   'cellular component organization or biogenesis',
#   'GO:0071840',
#   ['P77774',
#    'P0A940',
#    'P0A937',
#    'P62399',
#    'P02931',
#    'P77774',
#    'P0A940',
#    'P0A937',
#    'P76506',
#    'P0A7G2',
#    'P0A908']),
#  (0.1620848624398625,
#   'single-species biofilm formation on inanimate substrate',
#   'GO:0044011',
#   ['P0ACF8']),
#  (0.1620848624398625,
#   'iron import into cell',
#   'GO:0033212',
#   ['P05825', 'P05825']),
#  (0.1620848624398625,
#   'cellular response to metal ion',
#   'GO:0071248',
#   ['P77330']),
#  (0.1620848624398625, 'response to copper ion', 'GO:0046688', ['P0AB40']),
#  (0.17478410302746464,
#   'amide biosynthetic process',
#   'GO:0043604',
#   ['P0A6K3', 'P0A7K2', 'P62399', 'P0ACF8']),
#  (0.1871067748973574,
#   'multi-organism process',
#   'GO:0051704',
#   ['P0ACF8', 'P0A910', 'P0A927', 'P0A910', 'P0A910']),
#  (0.19128425681039354,
#   'L-alpha-amino acid transmembrane transport',
#   'GO:1902475',
#   ['P0AER8']),
#  (0.19128425681039354,
#   'cellular response to inorganic substance',
#   'GO:0071241',
#   ['P77330']),
#  (0.19128425681039354, 'response to cold', 'GO:0009409', ['P0A7G2']),
#  (0.19128425681039354, 'response to virus', 'GO:0009615', ['P0A910']),
#  (0.2194926852175846,
#   'ribosomal small subunit biogenesis',
#   'GO:0042274',
#   ['P0A7G2']),
#  (0.22868096731970036,
#   'response to external biotic stimulus',
#   'GO:0043207',
#   ['P0A910']),
#  (0.22868096731970036, 'response to other organism', 'GO:0051707', ['P0A910']),
#  (0.23139324274720666,
#   'multi-organism cellular process',
#   'GO:0044764',
#   ['P0ACF8', 'P0A910']),
#  (0.23776397311510825,
#   'cellular iron ion homeostasis',
#   'GO:0006879',
#   ['P05825', 'P05825']),
#  (0.2530364469743342,
#   'transmembrane transport',
#   'GO:0055085',
#   ['P02931', 'P0AER8', 'P0A910', 'P06129', 'P02930', 'P02931']),
#  (0.2556188354372583,
#   'glutamine family amino acid biosynthetic process',
#   'GO:0009084',
#   ['P0A9L8']),
#  (0.2597074547383493,
#   'cellular amide metabolic process',
#   'GO:0043603',
#   ['P0A6K3', 'P0A7K2', 'P62399', 'P0ACF8']),
#  (0.26439300016768874,
#   'single-species submerged biofilm formation',
#   'GO:0090609',
#   ['P0ACF8']),
#  (0.2730665052645004,
#   'ribosomal large subunit assembly',
#   'GO:0000027',
#   ['P62399']),
#  (0.2730665052645004,
#   'ribosomal large subunit biogenesis',
#   'GO:0042273',
#   ['P62399']),
#  (0.28835024774823637,
#   'ribonucleoprotein complex biogenesis',
#   'GO:0022613',
#   ['P0A7G2', 'P62399']),
#  (0.28835024774823637,
#   'ribosome biogenesis',
#   'GO:0042254',
#   ['P0A7G2', 'P62399']),
#  (0.2984942327532738,
#   'cellular response to starvation',
#   'GO:0009267',
#   ['P76344']),
#  (0.2984942327532738,
#   'cellular transition metal ion homeostasis',
#   'GO:0046916',
#   ['P05825', 'P05825']),
#  (0.3067762089460403,
#   'establishment of localization in cell',
#   'GO:0051649',
#   ['P05825', 'P05825']),
#  (0.3067762089460403,
#   'cellular metal ion homeostasis',
#   'GO:0006875',
#   ['P05825', 'P05825']),
#  (0.31496302039481,
#   'amino acid transmembrane transport',
#   'GO:0003333',
#   ['P0AER8']),
#  (0.31898057724041634,
#   'peptide transport',
#   'GO:0015833',
#   ['P05825', 'P75780']),
#  (0.32305573056255993,
#   'cellular response to nutrient levels',
#   'GO:0031669',
#   ['P76344']),
#  (0.3459094716934079,
#   'response to stimulus',
#   'GO:0050896',
#   ['P0ADB7',
#    'P0A937',
#    'P02930',
#    'P02931',
#    'P0AER8',
#    'P06129',
#    'P02930',
#    'P76344',
#    'P77330',
#    'P0AB40',
#    'P02930',
#    'P0A7G2',
#    'P0A910',
#    'P06996',
#    'P76344',
#    'P0A7G2',
#    'P0A910']),
#  (0.35282542020306246,
#   'cellular component organization',
#   'GO:0016043',
#   ['P77774',
#    'P0A940',
#    'P0A937',
#    'P62399',
#    'P02931',
#    'P77774',
#    'P0A940',
#    'P0A937',
#    'P76506']),
#  (0.3545064260403709, 'response to starvation', 'GO:0042594', ['P76344']),
#  (0.3547133863493818,
#   'protein metabolic process',
#   'GO:0019538',
#   ['P0A6K3', 'P0A6K3', 'P0A6K3', 'P0A7K2', 'P62399', 'P0ACF8', 'P09169']),
#  (0.36214418179237157, 'proteolysis', 'GO:0006508', ['P09169']),
#  (0.3696939787449251,
#   'cellular cation homeostasis',
#   'GO:0030003',
#   ['P05825', 'P05825']),
#  (0.3771568020365853,
#   'cellular ion homeostasis',
#   'GO:0006873',
#   ['P05825', 'P05825']),
#  (0.3845336260841673, 'rRNA processing', 'GO:0006364', ['P0A7G2']),
#  (0.3845336260841673, 'response to nutrient levels', 'GO:0031667', ['P76344']),
#  (0.3990331211842698,
#   'cellular chemical homeostasis',
#   'GO:0055082',
#   ['P05825', 'P05825']),
#  (0.4132000492212231,
#   'peptidoglycan biosynthetic process',
#   'GO:0009252',
#   ['P0A908']),
#  (0.4132000492212231,
#   'carboxylic acid transmembrane transport',
#   'GO:1905039',
#   ['P0AER8']),
#  (0.4132000492212231,
#   'organic acid transmembrane transport',
#   'GO:1903825',
#   ['P0AER8']),
#  (0.4132000492212231,
#   'glycosaminoglycan biosynthetic process',
#   'GO:0006024',
#   ['P0A908']),
#  (0.4132000492212231,
#   'aminoglycan biosynthetic process',
#   'GO:0006023',
#   ['P0A908']),
#  (0.42016112590567817,
#   'cell wall macromolecule biosynthetic process',
#   'GO:0044038',
#   ['P0A908']),
#  (0.42016112590567817,
#   'cellular component macromolecule biosynthetic process',
#   'GO:0070589',
#   ['P0A908']),
#  (0.4231674500105533,
#   'cellular protein metabolic process',
#   'GO:0044267',
#   ['P0A6K3', 'P0A6K3', 'P0A6K3', 'P0A7K2', 'P62399', 'P0ACF8']),
#  (0.4252779934762817,
#   'response to antibiotic',
#   'GO:0046677',
#   ['P0A937', 'P02930']),
#  (0.4293777598675187,
#   'response to external stimulus',
#   'GO:0009605',
#   ['P0A910', 'P76344']),
#  (0.43384306683963153,
#   'ribonucleoprotein complex assembly',
#   'GO:0022618',
#   ['P62399']),
#  (0.43384306683963153, 'ribosome assembly', 'GO:0042255', ['P62399']),
#  (0.44056572618717144, 'cell wall biogenesis', 'GO:0042546', ['P0A908']),
#  (0.44056572618717144, 'cell adhesion', 'GO:0007155', ['P0A940']),
#  (0.46027102573101897, 'regulation of translation', 'GO:0006417', ['P0ACF8']),
#  (0.46027102573101897,
#   'regulation of cellular amide metabolic process',
#   'GO:0034248',
#   ['P0ACF8']),
#  (0.4730309404924544,
#   'cell wall macromolecule metabolic process',
#   'GO:0044036',
#   ['P0A908']),
#  (0.4793003473097464,
#   'glutamine family amino acid metabolic process',
#   'GO:0009064',
#   ['P0A9L8']),
#  (0.4793003473097464,
#   'single-species biofilm formation',
#   'GO:0044010',
#   ['P0ACF8']),
#  (0.5095746692432056,
#   'regulation of cellular protein metabolic process',
#   'GO:0032268',
#   ['P0ACF8']),
#  (0.5095746692432056, 'biofilm formation', 'GO:0042710', ['P0ACF8']),
#  (0.5095746692432056,
#   'anion transmembrane transport',
#   'GO:0098656',
#   ['P0AER8']),
#  (0.537687309051596,
#   'protein-containing complex assembly',
#   'GO:0065003',
#   ['P62399', 'P02931']),
#  (0.5381336575857973, 'response to toxic substance', 'GO:0009636', ['P0ADB7']),
#  (0.5436480346975512,
#   'regulation of protein metabolic process',
#   'GO:0051246',
#   ['P0ACF8']),
#  (0.5436480346975512,
#   'cellular homeostasis',
#   'GO:0019725',
#   ['P05825', 'P05825']),
#  (0.5544852752898548,
#   'cellular response to extracellular stimulus',
#   'GO:0031668',
#   ['P76344']),
#  (0.5648007419183743,
#   'cellular response to stress',
#   'GO:0033554',
#   ['P0A7G2', 'P0A910', 'P06996', 'P76344']),
#  (0.5650719525373789, 'organelle assembly', 'GO:0070925', ['P62399']),
#  (0.5702730959621103,
#   'glycosaminoglycan metabolic process',
#   'GO:0030203',
#   ['P0A908']),
#  (0.5804944568474257,
#   'protein complex oligomerization',
#   'GO:0051259',
#   ['P02931']),
#  (0.5804944568474257,
#   'aminoglycan metabolic process',
#   'GO:0006022',
#   ['P0A908']),
#  (0.5894366245181433,
#   'organonitrogen compound biosynthetic process',
#   'GO:1901566',
#   ['P0A6K3', 'P0A7K2', 'P62399', 'P0ACF8', 'P0A9L8', 'P0A908']),
#  (0.5953843494559273,
#   'response to extracellular stimulus',
#   'GO:0009991',
#   ['P76344']),
#  (0.5974396317990945,
#   'cellular response to DNA damage stimulus',
#   'GO:0006974',
#   ['P0A7G2', 'P0A910', 'P06996']),
#  (0.62552773966456,
#   'protein-containing complex subunit organization',
#   'GO:0043933',
#   ['P62399', 'P02931']),
#  (0.6457068685834104, 'amino acid transport', 'GO:0006865', ['P0AER8']),
#  (0.6494080555344723,
#   'cellular response to stimulus',
#   'GO:0051716',
#   ['P0A7G2', 'P0A910', 'P06996', 'P76344', 'P77330']),
#  (0.6541775452822667,
#   'cell wall organization or biogenesis',
#   'GO:0071554',
#   ['P0A908']),
#  (0.6583386609975694,
#   'cellular response to chemical stimulus',
#   'GO:0070887',
#   ['P77330']),
#  (0.6745013299914165,
#   'negative regulation of transcription, DNA-templated',
#   'GO:0045892',
#   ['P0ACF8']),
#  (0.6745013299914165,
#   'negative regulation of nucleic acid-templated transcription',
#   'GO:1903507',
#   ['P0ACF8']),
#  (0.6745013299914165,
#   'negative regulation of RNA biosynthetic process',
#   'GO:1902679',
#   ['P0ACF8']),
#  (0.6823012092847723, 'ncRNA processing', 'GO:0034470', ['P0A7G2']),
#  (0.6899191146730725,
#   'negative regulation of RNA metabolic process',
#   'GO:0051253',
#   ['P0ACF8']),
#  (0.6973591764208471,
#   'negative regulation of nucleobase-containing compound metabolic process',
#   'GO:0045934',
#   ['P0ACF8']),
#  (0.7254204436285208, 'RNA processing', 'GO:0006396', ['P0A7G2']),
#  (0.735276643669122, 'carboxylic acid transport', 'GO:0046942', ['P0AER8']),
#  (0.7384848861140099, 'organic acid transport', 'GO:0015849', ['P0AER8']),
#  (0.7447882762311232,
#   'cellular protein modification process',
#   'GO:0006464',
#   ['P0A6K3', 'P0A6K3']),
#  (0.7447882762311232,
#   'alpha-amino acid biosynthetic process',
#   'GO:1901607',
#   ['P0A9L8']),
#  (0.7447882762311232,
#   'protein modification process',
#   'GO:0036211',
#   ['P0A6K3', 'P0A6K3']),
#  (0.7685560044554453,
#   'negative regulation of cellular macromolecule biosynthetic process',
#   'GO:2000113',
#   ['P0ACF8']),
#  (0.7685560044554453,
#   'negative regulation of macromolecule biosynthetic process',
#   'GO:0010558',
#   ['P0ACF8']),
#  (0.771371069490011,
#   'negative regulation of cellular biosynthetic process',
#   'GO:0031327',
#   ['P0ACF8']),
#  (0.771371069490011,
#   'negative regulation of biosynthetic process',
#   'GO:0009890',
#   ['P0ACF8']),
#  (0.7769016072364338, 'ncRNA metabolic process', 'GO:0034660', ['P0A7G2']),
#  (0.782301891668594,
#   'negative regulation of nitrogen compound metabolic process',
#   'GO:0051172',
#   ['P0ACF8']),
#  (0.7901646035632907,
#   'negative regulation of cellular metabolic process',
#   'GO:0031324',
#   ['P0ACF8']),
#  (0.7901646035632907,
#   'cellular amino acid biosynthetic process',
#   'GO:0008652',
#   ['P0A9L8']),
#  (0.7952521665513705,
#   'negative regulation of gene expression',
#   'GO:0010629',
#   ['P0ACF8']),
#  (0.8276526456414053,
#   'negative regulation of macromolecule metabolic process',
#   'GO:0010605',
#   ['P0ACF8']),
#  (0.8318533126989853,
#   'negative regulation of metabolic process',
#   'GO:0009892',
#   ['P0ACF8']),
#  (0.8495555044384341,
#   'negative regulation of cellular process',
#   'GO:0048523',
#   ['P0ACF8', 'P0ACF8']),
#  (0.8699008053499142,
#   'gene expression',
#   'GO:0010467',
#   ['P0A6K3', 'P0A7K2', 'P62399', 'P0ACF8', 'P0ACF8', 'P0A7G2']),
#  (0.8775911812619056,
#   'response to stress',
#   'GO:0006950',
#   ['P0A7G2', 'P0A910', 'P06996', 'P76344', 'P0A7G2']),
#  (0.8897422606808973,
#   'negative regulation of biological process',
#   'GO:0048519',
#   ['P0ACF8', 'P0ACF8']),
#  (0.8977066118903376,
#   'alpha-amino acid metabolic process',
#   'GO:1901605',
#   ['P0A9L8']),
#  (0.9039134790887923,
#   'carboxylic acid biosynthetic process',
#   'GO:0046394',
#   ['P0A9L8']),
#  (0.9039134790887923,
#   'organic acid biosynthetic process',
#   'GO:0016053',
#   ['P0A9L8']),
#  (0.9145677726513259,
#   'biological regulation',
#   'GO:0065007',
#   ['P05825',
#    'P05825',
#    'P13036',
#    'P06971',
#    'P75780',
#    'P0ACF8',
#    'P0ACF8',
#    'P0ACF8']),
#  (0.922025198416566,
#   'cellular macromolecule biosynthetic process',
#   'GO:0034645',
#   ['P0A6K3', 'P0A7K2', 'P62399', 'P0ACF8', 'P0ACF8', 'P0A908']),
#  (0.9252299988061019,
#   'macromolecule biosynthetic process',
#   'GO:0009059',
#   ['P0A6K3', 'P0A7K2', 'P62399', 'P0ACF8', 'P0ACF8', 'P0A908']),
#  (0.9339578419572699,
#   'organonitrogen compound metabolic process',
#   'GO:1901564',
#   ['P0A6K3',
#    'P0A6K3',
#    'P0A6K3',
#    'P0A7K2',
#    'P62399',
#    'P0ACF8',
#    'P09169',
#    'P0A9L8',
#    'P0A908']),
#  (0.9502059905415471,
#   'cellular amino acid metabolic process',
#   'GO:0006520',
#   ['P0A9L8']),
#  (0.9502059905415471,
#   'carbohydrate derivative biosynthetic process',
#   'GO:1901137',
#   ['P0A908']),
#  (0.9652201934793012,
#   'regulation of transcription, DNA-templated',
#   'GO:0006355',
#   ['P0ACF8']),
#  (0.9652201934793012,
#   'regulation of RNA biosynthetic process',
#   'GO:2001141',
#   ['P0ACF8']),
#  (0.9652201934793012,
#   'regulation of nucleic acid-templated transcription',
#   'GO:1903506',
#   ['P0ACF8']),
#  (0.969822418323175,
#   'regulation of RNA metabolic process',
#   'GO:0051252',
#   ['P0ACF8']),
#  (0.9731420420190136,
#   'regulation of nucleobase-containing compound metabolic process',
#   'GO:0019219',
#   ['P0ACF8']),
#  (0.9754756205436979,
#   'small molecule biosynthetic process',
#   'GO:0044283',
#   ['P0A9L8']),
#  (0.9789499735552468,
#   'cellular nitrogen compound biosynthetic process',
#   'GO:0044271',
#   ['P0A6K3', 'P0A7K2', 'P62399', 'P0ACF8', 'P0ACF8']),
#  (0.9823062837207126,
#   'regulation of cellular macromolecule biosynthetic process',
#   'GO:2000112',
#   ['P0ACF8', 'P0ACF8']),
#  (0.9825368816433381,
#   'transcription, DNA-templated',
#   'GO:0006351',
#   ['P0ACF8']),
#  (0.9825368816433381,
#   'nucleic acid-templated transcription',
#   'GO:0097659',
#   ['P0ACF8']),
#  (0.9825368816433381,
#   'regulation of macromolecule biosynthetic process',
#   'GO:0010556',
#   ['P0ACF8', 'P0ACF8']),
#  (0.9832112685344486,
#   'regulation of cellular biosynthetic process',
#   'GO:0031326',
#   ['P0ACF8', 'P0ACF8']),
#  (0.9836467095595566,
#   'regulation of biosynthetic process',
#   'GO:0009889',
#   ['P0ACF8', 'P0ACF8']),
#  (0.9846877925293095, 'RNA biosynthetic process', 'GO:0032774', ['P0ACF8']),
#  (0.9857412288443415,
#   'RNA metabolic process',
#   'GO:0016070',
#   ['P0ACF8', 'P0A7G2']),
#  (0.9858521705657889,
#   'regulation of gene expression',
#   'GO:0010468',
#   ['P0ACF8', 'P0ACF8']),
#  (0.9874388392869154,
#   'regulation of nitrogen compound metabolic process',
#   'GO:0051171',
#   ['P0ACF8', 'P0ACF8']),
#  (0.9888518421734437,
#   'regulation of primary metabolic process',
#   'GO:0080090',
#   ['P0ACF8', 'P0ACF8']),
#  (0.9889989469664474,
#   'regulation of cellular metabolic process',
#   'GO:0031323',
#   ['P0ACF8', 'P0ACF8']),
#  (0.9901097163809656,
#   'carbohydrate derivative metabolic process',
#   'GO:1901135',
#   ['P0A908']),
#  (0.9907476910536777,
#   'regulation of macromolecule metabolic process',
#   'GO:0060255',
#   ['P0ACF8', 'P0ACF8']),
#  (0.9926311687933163,
#   'regulation of metabolic process',
#   'GO:0019222',
#   ['P0ACF8', 'P0ACF8']),
#  (0.9957048963641446,
#   'heterocycle biosynthetic process',
#   'GO:0018130',
#   ['P0ACF8', 'P0A9L8']),
#  (0.9962797573848915,
#   'macromolecule metabolic process',
#   'GO:0043170',
#   ['P0A6K3',
#    'P0A6K3',
#    'P0A6K3',
#    'P0A7K2',
#    'P62399',
#    'P0ACF8',
#    'P09169',
#    'P0ACF8',
#    'P0A908',
#    'P0A7G2']),
#  (0.9964034818927825,
#   'organic cyclic compound biosynthetic process',
#   'GO:1901362',
#   ['P0ACF8', 'P0A9L8']),
#  (0.9970940637796096,
#   'organic substance biosynthetic process',
#   'GO:1901576',
#   ['P0A6K3', 'P0A7K2', 'P62399', 'P0ACF8', 'P0ACF8', 'P0A908', 'P0A9L8']),
#  (0.9971277877363143,
#   'cellular biosynthetic process',
#   'GO:0044249',
#   ['P0A6K3', 'P0A7K2', 'P62399', 'P0ACF8', 'P0ACF8', 'P0A908', 'P0A9L8']),
#  (0.9974538622873086,
#   'carboxylic acid metabolic process',
#   'GO:0019752',
#   ['P0A9L8']),
#  (0.9977831169852954,
#   'nucleobase-containing compound biosynthetic process',
#   'GO:0034654',
#   ['P0ACF8']),
#  (0.9979623581700905,
#   'biosynthetic process',
#   'GO:0009058',
#   ['P0A6K3', 'P0A7K2', 'P62399', 'P0ACF8', 'P0ACF8', 'P0A908', 'P0A9L8']),
#  (0.9983401310344165,
#   'cellular macromolecule metabolic process',
#   'GO:0044260',
#   ['P0A6K3',
#    'P0A6K3',
#    'P0A6K3',
#    'P0A7K2',
#    'P62399',
#    'P0ACF8',
#    'P0ACF8',
#    'P0A908']),
#  (0.9984354017573132,
#   'organic acid metabolic process',
#   'GO:0006082',
#   ['P0A9L8']),
#  (0.9985207021591869,
#   'regulation of cellular process',
#   'GO:0050794',
#   ['P0ACF8', 'P0ACF8', 'P0ACF8']),
#  (0.9989494321726179,
#   'nucleic acid metabolic process',
#   'GO:0090304',
#   ['P0ACF8', 'P0A7G2']),
#  (0.9991595097232419,
#   'regulation of biological process',
#   'GO:0050789',
#   ['P0ACF8', 'P0ACF8', 'P0ACF8']),
#  (0.9993775341499005,
#   'aromatic compound biosynthetic process',
#   'GO:0019438',
#   ['P0ACF8']),
#  (0.9996795267234329,
#   'cellular nitrogen compound metabolic process',
#   'GO:0034641',
#   ['P0A6K3', 'P0A7K2', 'P62399', 'P0ACF8', 'P0ACF8', 'P0A7G2']),
#  (0.9998923683724174,
#   'nitrogen compound metabolic process',
#   'GO:0006807',
#   ['P0A6K3',
#    'P0A6K3',
#    'P0A6K3',
#    'P0A7K2',
#    'P62399',
#    'P0ACF8',
#    'P09169',
#    'P0A9L8',
#    'P0A908',
#    'P0ACF8',
#    'P0A7G2']),
#  (0.9999201489103801,
#   'heterocycle metabolic process',
#   'GO:0046483',
#   ['P0ACF8', 'P0A7G2', 'P0A9L8']),
#  (0.9999458629497031,
#   'nucleobase-containing compound metabolic process',
#   'GO:0006139',
#   ['P0ACF8', 'P0A7G2']),
#  (0.9999573460425063,
#   'organic cyclic compound metabolic process',
#   'GO:1901360',
#   ['P0ACF8', 'P0A7G2', 'P0A9L8']),
#  (0.9999887695201162,
#   'small molecule metabolic process',
#   'GO:0044281',
#   ['P0A9L8']),
#  (0.9999926712384618,
#   'cellular aromatic compound metabolic process',
#   'GO:0006725',
#   ['P0ACF8', 'P0A7G2']),
#  (0.9999982369743188,
#   'cellular process',
#   'GO:0009987',
#   ['P77774',
#    'P0A940',
#    'P0A937',
#    'P62399',
#    'P02931',
#    'P77774',
#    'P0A940',
#    'P0A937',
#    'P76506',
#    'P0A6K3',
#    'P0A6K3',
#    'P0A6K3',
#    'P0A7K2',
#    'P62399',
#    'P0ACF8',
#    'P0ACF8',
#    'P0A908',
#    'P0A9L8',
#    'P0A7G2',
#    'P05825',
#    'P05825',
#    'P0ACF8',
#    'P0A910',
#    'P0A7G2',
#    'P0A910',
#    'P06996',
#    'P76344',
#    'P77330']),
#  (0.9999986827634597,
#   'primary metabolic process',
#   'GO:0044238',
#   ['P0A6K3',
#    'P0A6K3',
#    'P0A6K3',
#    'P0A7K2',
#    'P62399',
#    'P0ACF8',
#    'P09169',
#    'P0ACF8',
#    'P0A7G2',
#    'P0A9L8']),
#  (0.9999999851484336,
#   'organic substance metabolic process',
#   'GO:0071704',
#   ['P0A6K3',
#    'P0A6K3',
#    'P0A6K3',
#    'P0A7K2',
#    'P62399',
#    'P0ACF8',
#    'P09169',
#    'P0ACF8',
#    'P0A908',
#    'P0A7G2',
#    'P0A9L8']),
#  (0.9999999938841001,
#   'cellular metabolic process',
#   'GO:0044237',
#   ['P0A6K3',
#    'P0A6K3',
#    'P0A6K3',
#    'P0A7K2',
#    'P62399',
#    'P0ACF8',
#    'P0ACF8',
#    'P0A908',
#    'P0A9L8',
#    'P0A7G2']),
#  (0.9999999995641846,
#   'metabolic process',
#   'GO:0008152',
#   ['P0A6K3',
#    'P0A6K3',
#    'P0A6K3',
#    'P0A7K2',
#    'P62399',
#    'P0ACF8',
#    'P09169',
#    'P0ACF8',
#    'P0A908',
#    'P0A7G2',
#    'P0A9L8']),
#  (1.0,
#   'biological_process',
#   'GO:0008150',
#   ['P77774',
#    'P0A940',
#    'P0A937',
#    'P62399',
#    'P02931',
#    'P77774',
#    'P0A940',
#    'P0A937',
#    'P76506',
#    'P0A6K3',
#    'P0A6K3',
#    'P0A6K3',
#    'P0A7K2',
#    'P62399',
#    'P0ACF8',
#    'P0ACF8',
#    'P0A908',
#    'P0A9L8',
#    'P0A7G2',
#    'P05825',
#    'P05825',
#    'P0ACF8',
#    'P0A910',
#    'P0A7G2',
#    'P0A910',
#    'P06996',
#    'P76344',
#    'P77330',
#    'P06996',
#    'P05825',
#    'P75780',
#    'P0AER8',
#    'P0A927',
#    'P06129',
#    'P02930',
#    'P0A927',
#    'P0A910',
#    'P13036',
#    'P13036',
#    'P06971',
#    'P75780',
#    'P0A910',
#    'P06129',
#    'P02930',
#    'P02931',
#    'P02931',
#    'P02930',
#    'P0A940',
#    'P09169',
#    'P13036',
#    'P06971',
#    'P75780',
#    'P0ADB7',
#    'P0A937',
#    'P02930',
#    'P76344',
#    'P0AB40',
#    'P02930',
#    'P0A7G2',
#    'P0A910',
#    'P0A927',
#    'P0A910'])]

# %% [markdown]
# ## Une première application: représentation riche du résultat de l'analyse
#
#
# ### Mise en forme "riche" des résultats grâce au notebook
#
# Jupyter permet d'étendre le concept de la méthode **__str__()** afin de produire du contenu HTML.
#  Ainsi, tout objet impémentant une méthode **_repr_html_()** sera affiché, via son rendu HTML, dans la cellule d'un notebook.
#
# ```python
# class Point():
#     def __init__(self, x, y, z):
#         self.x = x
#         self.y = y
#         self.z = z
#     def _repr_html_(self):
#         htmlString = "<table><thead><tr><td>Abscisse</td><td>Ordonnée</td><td>Cote</td></tr></thead>"
#         htmlString += f"<tbody><tr><td>{self.x}</td><td>{self.y}</td><td>{self.z}</td></tr></tbody></table>"
#         return htmlString
# Point(2,3,4)
# ```
# Affichera
#
# ![caption](../figs/reprhtml.png)
#
#
# ### Intégration des résultats à la visualisation du notebook
#
# En vous inspirant de la fonction ci-dessus, implémenter une classe Rich_GO_ORA dont la méthode [`_repr_html_`](https://ipython.readthedocs.io/en/stable/config/integrating.html) permettra un affichage plus lisible d'une des analyses `biological_process / molecular_function /cellular_component`
#
# Un exemple possible est,
# ![caption](../figs/_repr_html_.png)
#
# (Bonus): clicker sur le nom du terme GO envoie vers sa description.
# Pour cela, afficher le nom du pathway dans une balise hyperlien pour permettre d'acceder à la page de description du terme GO.
#
# Les termes GO sont accessibles aux URL de la forme
# `http://amigo.geneontology.org/amigo/term/GO:GO_NUMBER`.

# %%
class Point():
    def __init__(self, x, y, z):
        self.x = x
        self.y = y
        self.z = z
    def _repr_html_(self):
        htmlString = "<table><thead><tr><td>Abscisse</td><td>Ordonnée</td><td>Cote</td></tr></thead>"
        htmlString += f"<tbody><tr><td>{self.x}</td><td>{self.y}</td><td>{self.z}</td></tr></tbody></table>"
        return htmlString
Point(2,3,4)
# Out:
# <table><thead><tr><td>Abscisse</td><td>Ordonnée</td><td>Cote</td></tr></thead><tbody><tr><td>2</td><td>3</td><td>4</td></tr></tbody></table>

# %%
bp_sup5
# Out:
# [(1.277774972034038e-06,
#   'siderophore transport',
#   'GO:0015891',
#   ['P13036', 'P06971', 'P75780', 'P02930', 'P05825']),
#  (6.023913047836394e-06,
#   'iron coordination entity transport',
#   'GO:1901678',
#   ['P05825', 'P05825', 'P13036', 'P06971', 'P75780', 'P02930']),
#  (5.532051927766727e-05,
#   'iron ion transport',
#   'GO:0006826',
#   ['P13036', 'P05825', 'P05825', 'P13036', 'P06971', 'P75780', 'P02930']),
#  (0.0001270732486959893,
#   'ion transport',
#   'GO:0006811',
#   ['P0A927',
#    'P0A910',
#    'P13036',
#    'P05825',
#    'P05825',
#    'P13036',
#    'P06971',
#    'P75780',
#    'P02930',
#    'P0AER8',
#    'P06996',
#    'P76506',
#    'P0A910',
#    'P06129',
#    'P02930',
#    'P02931']),
#  (0.00023017691092962867,
#   'membrane organization',
#   'GO:0061024',
#   ['P77774', 'P0A940', 'P0A937', 'P77774', 'P0A940', 'P0A937', 'P76506']),
#  (0.00038932504762125263,
#   'protein insertion into membrane',
#   'GO:0051205',
#   ['P77774', 'P0A940', 'P0A937']),
#  (0.0006094525728954648,
#   'Gram-negative-bacterium-type cell outer membrane assembly',
#   'GO:0043165',
#   ['P77774', 'P0A940', 'P0A937']),
#  (0.0006094525728954648,
#   'membrane assembly',
#   'GO:0071709',
#   ['P77774', 'P0A940', 'P0A937']),
#  (0.0007440622520732061,
#   'establishment of protein localization to membrane',
#   'GO:0090150',
#   ['P77774', 'P0A940', 'P0A937']),
#  (0.0009756392518373065,
#   'iron ion homeostasis',
#   'GO:0055072',
#   ['P13036', 'P06971', 'P75780', 'P05825', 'P05825']),
#  (0.0013025572322994698,
#   'phospholipid transport',
#   'GO:0015914',
#   ['P06996', 'P76506']),
#  (0.001825589084162934,
#   'transition metal ion homeostasis',
#   'GO:0055076',
#   ['P05825', 'P05825', 'P13036', 'P06971', 'P75780']),
#  (0.0019788009948913735,
#   'metal ion homeostasis',
#   'GO:0055065',
#   ['P05825', 'P05825', 'P13036', 'P06971', 'P75780']),
#  (0.002135325180678235,
#   'establishment of localization',
#   'GO:0051234',
#   ['P77774',
#    'P0A940',
#    'P0A937',
#    'P05825',
#    'P75780',
#    'P0AER8',
#    'P0A927',
#    'P06129',
#    'P02930',
#    'P05825',
#    'P06996',
#    'P76506',
#    'P0A927',
#    'P0A910',
#    'P13036',
#    'P05825',
#    'P13036',
#    'P06971',
#    'P75780',
#    'P0A910',
#    'P06129',
#    'P02930',
#    'P02931',
#    'P02931',
#    'P02930']),
#  (0.0024917150479736015,
#   'cellular localization',
#   'GO:0051641',
#   ['P77774', 'P0A940', 'P0A937', 'P05825', 'P05825']),
#  (0.002842060716026531,
#   'cofactor transport',
#   'GO:0051181',
#   ['P02930', 'P05825', 'P06129']),
#  (0.003779643414969773,
#   'cation homeostasis',
#   'GO:0055080',
#   ['P05825', 'P05825', 'P13036', 'P06971', 'P75780']),
#  (0.004031108403003663,
#   'ion homeostasis',
#   'GO:0050801',
#   ['P05825', 'P05825', 'P13036', 'P06971', 'P75780']),
#  (0.00455270063425091,
#   'enterobactin transport',
#   'GO:0042930',
#   ['P02930', 'P05825']),
#  (0.004819061440716164,
#   'cellular protein localization',
#   'GO:0034613',
#   ['P77774', 'P0A940', 'P0A937']),
#  (0.004819061440716164,
#   'cellular macromolecule localization',
#   'GO:0070727',
#   ['P77774', 'P0A940', 'P0A937']),
#  (0.004853313854698309,
#   'chemical homeostasis',
#   'GO:0048878',
#   ['P05825', 'P05825', 'P13036', 'P06971', 'P75780']),
#  (0.005098199016710273,
#   'localization',
#   'GO:0051179',
#   ['P77774',
#    'P0A940',
#    'P0A937',
#    'P06996',
#    'P76506',
#    'P05825',
#    'P75780',
#    'P0AER8',
#    'P0A927',
#    'P06129',
#    'P02930',
#    'P05825',
#    'P0A927',
#    'P0A910',
#    'P13036',
#    'P05825',
#    'P13036',
#    'P06971',
#    'P75780',
#    'P0A910',
#    'P06129',
#    'P02930',
#    'P02931',
#    'P02931',
#    'P02930']),
#  (0.00758232913911829,
#   'drug transport',
#   'GO:0015893',
#   ['P02931', 'P0AER8', 'P06129', 'P02930']),
#  (0.01109230073813465,
#   'viral entry into host cell',
#   'GO:0046718',
#   ['P0A927', 'P0A910']),
#  (0.011694058154235146,
#   'co-translational protein modification',
#   'GO:0043686',
#   ['P0A6K3']),
#  (0.011694058154235146, 'detection of virus', 'GO:0009597', ['P0A910']),
#  (0.012785797566823636,
#   'macromolecule localization',
#   'GO:0033036',
#   ['P77774', 'P0A940', 'P0A937', 'P06996', 'P76506']),
#  (0.013215086461965446,
#   'ion transmembrane transport',
#   'GO:0034220',
#   ['P0A910', 'P06129', 'P02930', 'P02931', 'P0AER8']),
#  (0.015101071813365109,
#   'homeostatic process',
#   'GO:0042592',
#   ['P05825', 'P05825', 'P13036', 'P06971', 'P75780']),
#  (0.01777216828190163,
#   'response to metal ion',
#   'GO:0010038',
#   ['P76344', 'P77330', 'P0AB40']),
#  (0.019718028893727195,
#   'organic anion transport',
#   'GO:0015711',
#   ['P02930', 'P05825', 'P0AER8', 'P06996', 'P76506']),
#  (0.022162914789973308, 'lipid transport', 'GO:0006869', ['P06996', 'P76506']),
#  (0.022554827580056305,
#   'response to chemical',
#   'GO:0042221',
#   ['P0ADB7',
#    'P0A937',
#    'P02930',
#    'P02931',
#    'P0AER8',
#    'P06129',
#    'P02930',
#    'P76344',
#    'P77330',
#    'P0AB40',
#    'P02930']),
#  (0.02325501921913976,
#   'intermembrane phospholipid transfer',
#   'GO:0120010',
#   ['P76506']),
#  (0.02325501921913976,
#   'cellular response to zinc ion starvation',
#   'GO:0034224',
#   ['P76344']),
#  (0.02325501921913976,
#   'cellular response to magnesium ion',
#   'GO:0071286',
#   ['P77330']),
#  (0.02325501921913976, 'colicin transport', 'GO:0042914', ['P05825']),
#  (0.028871685432643505,
#   'interaction with host',
#   'GO:0051701',
#   ['P0A927', 'P0A910']),
#  (0.03258358726458561,
#   'anion transport',
#   'GO:0006820',
#   ['P02930', 'P05825', 'P0AER8', 'P06996', 'P76506']),
#  (0.033537505530004855,
#   'transport',
#   'GO:0006810',
#   ['P05825',
#    'P75780',
#    'P0AER8',
#    'P0A927',
#    'P06129',
#    'P02930',
#    'P05825',
#    'P06996',
#    'P76506',
#    'P0A927',
#    'P0A910',
#    'P13036',
#    'P05825',
#    'P13036',
#    'P06971',
#    'P75780',
#    'P0A910',
#    'P06129',
#    'P02930',
#    'P02931',
#    'P02931',
#    'P02930']),
#  (0.03468435643890315,
#   'L-proline biosynthetic process',
#   'GO:0055129',
#   ['P0A9L8']),
#  (0.03468435643890315, 'maturation of SSU-rRNA', 'GO:0030490', ['P0A7G2']),
#  (0.03468435643890315, 'conjugation', 'GO:0000746', ['P0A910']),
#  (0.03468435643890315,
#   'L-glutamate transmembrane transport',
#   'GO:0015813',
#   ['P0AER8']),
#  (0.03468435643890315,
#   'response to organic cyclic compound',
#   'GO:0014070',
#   ['P02930']),
#  (0.045983527211367746,
#   'proline biosynthetic process',
#   'GO:0006561',
#   ['P0A9L8']),
#  (0.045983527211367746, 'proline metabolic process', 'GO:0006560', ['P0A9L8']),
#  (0.045983527211367746,
#   'negative regulation of single-species biofilm formation on inanimate substrate',
#   'GO:1900232',
#   ['P0ACF8']),
#  (0.045983527211367746,
#   'intermembrane lipid transfer',
#   'GO:0120009',
#   ['P76506']),
#  (0.045983527211367746, 'drug export', 'GO:0046618', ['P02930']),
#  (0.045983527211367746, 'response to cadmium ion', 'GO:0046686', ['P76344']),
#  (0.05006324988424036,
#   'symbiotic process',
#   'GO:0044403',
#   ['P0A927', 'P0A910']),
#  (0.057153973253513124,
#   'N-terminal protein amino acid modification',
#   'GO:0031365',
#   ['P0A6K3']),
#  (0.057153973253513124,
#   'negative regulation of single-species biofilm formation',
#   'GO:1900191',
#   ['P0ACF8']),
#  (0.057153973253513124, 'cobalamin transport', 'GO:0015889', ['P06129']),
#  (0.057153973253513124,
#   'negative regulation of multi-organism process',
#   'GO:0043901',
#   ['P0ACF8']),
#  (0.06541576469927579,
#   'interspecies interaction between organisms',
#   'GO:0044419',
#   ['P0A927', 'P0A910']),
#  (0.0681971207652637,
#   'ferric-enterobactin import into cell',
#   'GO:0015685',
#   ['P05825']),
#  (0.0681971207652637, 'nucleoside transport', 'GO:0015858', ['P0A927']),
#  (0.06948027078084751,
#   'response to inorganic substance',
#   'GO:0010035',
#   ['P76344', 'P77330', 'P0AB40']),
#  (0.07706624637920949,
#   'cellular component biogenesis',
#   'GO:0044085',
#   ['P77774', 'P0A940', 'P0A937', 'P62399', 'P02931', 'P0A7G2', 'P0A908']),
#  (0.07911438059163647, 'protein homotrimerization', 'GO:0070207', ['P02931']),
#  (0.07911438059163647,
#   'regulation of single-species biofilm formation on inanimate substrate',
#   'GO:1900231',
#   ['P0ACF8']),
#  (0.07911438059163647, 'microcin transport', 'GO:0042884', ['P75780']),
#  (0.08027757662824633,
#   'translation',
#   'GO:0006412',
#   ['P0A6K3', 'P0A7K2', 'P62399', 'P0ACF8']),
#  (0.08423347914867976,
#   'organic substance transport',
#   'GO:0071702',
#   ['P05825',
#    'P75780',
#    'P02930',
#    'P05825',
#    'P0AER8',
#    'P06996',
#    'P76506',
#    'P0A927',
#    'P06129']),
#  (0.09272646695575094,
#   'drug transmembrane transport',
#   'GO:0006855',
#   ['P02931', 'P0AER8']),
#  (0.09569991493111658,
#   'establishment of protein localization',
#   'GO:0045184',
#   ['P77774', 'P0A940', 'P0A937']),
#  (0.09804917169904069,
#   'protein localization',
#   'GO:0008104',
#   ['P77774', 'P0A940', 'P0A937']),
#  (0.10057680475517819,
#   'siderophore-dependent iron import into cell',
#   'GO:0033214',
#   ['P05825', 'P05825']),
#  (0.10121118644051987,
#   'peptide biosynthetic process',
#   'GO:0043043',
#   ['P0A6K3', 'P0A7K2', 'P62399', 'P0ACF8']),
#  (0.11112471544426171,
#   'nucleobase-containing compound transport',
#   'GO:0015931',
#   ['P0A927']),
#  (0.12650723587630439,
#   'peptide metabolic process',
#   'GO:0006518',
#   ['P0A6K3', 'P0A7K2', 'P62399', 'P0ACF8']),
#  (0.13083265531786187,
#   'cellular component assembly',
#   'GO:0022607',
#   ['P77774', 'P0A940', 'P0A937', 'P62399', 'P02931']),
#  (0.14517621926894583,
#   'nitrogen compound transport',
#   'GO:0071705',
#   ['P05825', 'P75780', 'P0AER8', 'P0A927', 'P06129']),
#  (0.15212570404290615,
#   'regulation of single-species biofilm formation',
#   'GO:1900190',
#   ['P0ACF8']),
#  (0.15212570404290615,
#   'regulation of multi-organism process',
#   'GO:0043900',
#   ['P0ACF8']),
#  (0.15877553680823658,
#   'cellular component organization or biogenesis',
#   'GO:0071840',
#   ['P77774',
#    'P0A940',
#    'P0A937',
#    'P62399',
#    'P02931',
#    'P77774',
#    'P0A940',
#    'P0A937',
#    'P76506',
#    'P0A7G2',
#    'P0A908']),
#  (0.1620848624398625,
#   'single-species biofilm formation on inanimate substrate',
#   'GO:0044011',
#   ['P0ACF8']),
#  (0.1620848624398625,
#   'iron import into cell',
#   'GO:0033212',
#   ['P05825', 'P05825']),
#  (0.1620848624398625,
#   'cellular response to metal ion',
#   'GO:0071248',
#   ['P77330']),
#  (0.1620848624398625, 'response to copper ion', 'GO:0046688', ['P0AB40']),
#  (0.17478410302746464,
#   'amide biosynthetic process',
#   'GO:0043604',
#   ['P0A6K3', 'P0A7K2', 'P62399', 'P0ACF8']),
#  (0.1871067748973574,
#   'multi-organism process',
#   'GO:0051704',
#   ['P0ACF8', 'P0A910', 'P0A927', 'P0A910', 'P0A910']),
#  (0.19128425681039354,
#   'L-alpha-amino acid transmembrane transport',
#   'GO:1902475',
#   ['P0AER8']),
#  (0.19128425681039354,
#   'cellular response to inorganic substance',
#   'GO:0071241',
#   ['P77330']),
#  (0.19128425681039354, 'response to cold', 'GO:0009409', ['P0A7G2']),
#  (0.19128425681039354, 'response to virus', 'GO:0009615', ['P0A910']),
#  (0.2194926852175846,
#   'ribosomal small subunit biogenesis',
#   'GO:0042274',
#   ['P0A7G2']),
#  (0.22868096731970036,
#   'response to external biotic stimulus',
#   'GO:0043207',
#   ['P0A910']),
#  (0.22868096731970036, 'response to other organism', 'GO:0051707', ['P0A910']),
#  (0.23139324274720666,
#   'multi-organism cellular process',
#   'GO:0044764',
#   ['P0ACF8', 'P0A910']),
#  (0.23776397311510825,
#   'cellular iron ion homeostasis',
#   'GO:0006879',
#   ['P05825', 'P05825']),
#  (0.2530364469743342,
#   'transmembrane transport',
#   'GO:0055085',
#   ['P02931', 'P0AER8', 'P0A910', 'P06129', 'P02930', 'P02931']),
#  (0.2556188354372583,
#   'glutamine family amino acid biosynthetic process',
#   'GO:0009084',
#   ['P0A9L8']),
#  (0.2597074547383493,
#   'cellular amide metabolic process',
#   'GO:0043603',
#   ['P0A6K3', 'P0A7K2', 'P62399', 'P0ACF8']),
#  (0.26439300016768874,
#   'single-species submerged biofilm formation',
#   'GO:0090609',
#   ['P0ACF8']),
#  (0.2730665052645004,
#   'ribosomal large subunit assembly',
#   'GO:0000027',
#   ['P62399']),
#  (0.2730665052645004,
#   'ribosomal large subunit biogenesis',
#   'GO:0042273',
#   ['P62399']),
#  (0.28835024774823637,
#   'ribonucleoprotein complex biogenesis',
#   'GO:0022613',
#   ['P0A7G2', 'P62399']),
#  (0.28835024774823637,
#   'ribosome biogenesis',
#   'GO:0042254',
#   ['P0A7G2', 'P62399']),
#  (0.2984942327532738,
#   'cellular response to starvation',
#   'GO:0009267',
#   ['P76344']),
#  (0.2984942327532738,
#   'cellular transition metal ion homeostasis',
#   'GO:0046916',
#   ['P05825', 'P05825']),
#  (0.3067762089460403,
#   'establishment of localization in cell',
#   'GO:0051649',
#   ['P05825', 'P05825']),
#  (0.3067762089460403,
#   'cellular metal ion homeostasis',
#   'GO:0006875',
#   ['P05825', 'P05825']),
#  (0.31496302039481,
#   'amino acid transmembrane transport',
#   'GO:0003333',
#   ['P0AER8']),
#  (0.31898057724041634,
#   'peptide transport',
#   'GO:0015833',
#   ['P05825', 'P75780']),
#  (0.32305573056255993,
#   'cellular response to nutrient levels',
#   'GO:0031669',
#   ['P76344']),
#  (0.3459094716934079,
#   'response to stimulus',
#   'GO:0050896',
#   ['P0ADB7',
#    'P0A937',
#    'P02930',
#    'P02931',
#    'P0AER8',
#    'P06129',
#    'P02930',
#    'P76344',
#    'P77330',
#    'P0AB40',
#    'P02930',
#    'P0A7G2',
#    'P0A910',
#    'P06996',
#    'P76344',
#    'P0A7G2',
#    'P0A910']),
#  (0.35282542020306246,
#   'cellular component organization',
#   'GO:0016043',
#   ['P77774',
#    'P0A940',
#    'P0A937',
#    'P62399',
#    'P02931',
#    'P77774',
#    'P0A940',
#    'P0A937',
#    'P76506']),
#  (0.3545064260403709, 'response to starvation', 'GO:0042594', ['P76344']),
#  (0.3547133863493818,
#   'protein metabolic process',
#   'GO:0019538',
#   ['P0A6K3', 'P0A6K3', 'P0A6K3', 'P0A7K2', 'P62399', 'P0ACF8', 'P09169']),
#  (0.36214418179237157, 'proteolysis', 'GO:0006508', ['P09169']),
#  (0.3696939787449251,
#   'cellular cation homeostasis',
#   'GO:0030003',
#   ['P05825', 'P05825']),
#  (0.3771568020365853,
#   'cellular ion homeostasis',
#   'GO:0006873',
#   ['P05825', 'P05825']),
#  (0.3845336260841673, 'rRNA processing', 'GO:0006364', ['P0A7G2']),
#  (0.3845336260841673, 'response to nutrient levels', 'GO:0031667', ['P76344']),
#  (0.3990331211842698,
#   'cellular chemical homeostasis',
#   'GO:0055082',
#   ['P05825', 'P05825']),
#  (0.4132000492212231,
#   'peptidoglycan biosynthetic process',
#   'GO:0009252',
#   ['P0A908']),
#  (0.4132000492212231,
#   'carboxylic acid transmembrane transport',
#   'GO:1905039',
#   ['P0AER8']),
#  (0.4132000492212231,
#   'organic acid transmembrane transport',
#   'GO:1903825',
#   ['P0AER8']),
#  (0.4132000492212231,
#   'glycosaminoglycan biosynthetic process',
#   'GO:0006024',
#   ['P0A908']),
#  (0.4132000492212231,
#   'aminoglycan biosynthetic process',
#   'GO:0006023',
#   ['P0A908']),
#  (0.42016112590567817,
#   'cell wall macromolecule biosynthetic process',
#   'GO:0044038',
#   ['P0A908']),
#  (0.42016112590567817,
#   'cellular component macromolecule biosynthetic process',
#   'GO:0070589',
#   ['P0A908']),
#  (0.4231674500105533,
#   'cellular protein metabolic process',
#   'GO:0044267',
#   ['P0A6K3', 'P0A6K3', 'P0A6K3', 'P0A7K2', 'P62399', 'P0ACF8']),
#  (0.4252779934762817,
#   'response to antibiotic',
#   'GO:0046677',
#   ['P0A937', 'P02930']),
#  (0.4293777598675187,
#   'response to external stimulus',
#   'GO:0009605',
#   ['P0A910', 'P76344']),
#  (0.43384306683963153,
#   'ribonucleoprotein complex assembly',
#   'GO:0022618',
#   ['P62399']),
#  (0.43384306683963153, 'ribosome assembly', 'GO:0042255', ['P62399']),
#  (0.44056572618717144, 'cell wall biogenesis', 'GO:0042546', ['P0A908']),
#  (0.44056572618717144, 'cell adhesion', 'GO:0007155', ['P0A940']),
#  (0.46027102573101897, 'regulation of translation', 'GO:0006417', ['P0ACF8']),
#  (0.46027102573101897,
#   'regulation of cellular amide metabolic process',
#   'GO:0034248',
#   ['P0ACF8']),
#  (0.4730309404924544,
#   'cell wall macromolecule metabolic process',
#   'GO:0044036',
#   ['P0A908']),
#  (0.4793003473097464,
#   'glutamine family amino acid metabolic process',
#   'GO:0009064',
#   ['P0A9L8']),
#  (0.4793003473097464,
#   'single-species biofilm formation',
#   'GO:0044010',
#   ['P0ACF8']),
#  (0.5095746692432056,
#   'regulation of cellular protein metabolic process',
#   'GO:0032268',
#   ['P0ACF8']),
#  (0.5095746692432056, 'biofilm formation', 'GO:0042710', ['P0ACF8']),
#  (0.5095746692432056,
#   'anion transmembrane transport',
#   'GO:0098656',
#   ['P0AER8']),
#  (0.537687309051596,
#   'protein-containing complex assembly',
#   'GO:0065003',
#   ['P62399', 'P02931']),
#  (0.5381336575857973, 'response to toxic substance', 'GO:0009636', ['P0ADB7']),
#  (0.5436480346975512,
#   'regulation of protein metabolic process',
#   'GO:0051246',
#   ['P0ACF8']),
#  (0.5436480346975512,
#   'cellular homeostasis',
#   'GO:0019725',
#   ['P05825', 'P05825']),
#  (0.5544852752898548,
#   'cellular response to extracellular stimulus',
#   'GO:0031668',
#   ['P76344']),
#  (0.5648007419183743,
#   'cellular response to stress',
#   'GO:0033554',
#   ['P0A7G2', 'P0A910', 'P06996', 'P76344']),
#  (0.5650719525373789, 'organelle assembly', 'GO:0070925', ['P62399']),
#  (0.5702730959621103,
#   'glycosaminoglycan metabolic process',
#   'GO:0030203',
#   ['P0A908']),
#  (0.5804944568474257,
#   'protein complex oligomerization',
#   'GO:0051259',
#   ['P02931']),
#  (0.5804944568474257,
#   'aminoglycan metabolic process',
#   'GO:0006022',
#   ['P0A908']),
#  (0.5894366245181433,
#   'organonitrogen compound biosynthetic process',
#   'GO:1901566',
#   ['P0A6K3', 'P0A7K2', 'P62399', 'P0ACF8', 'P0A9L8', 'P0A908']),
#  (0.5953843494559273,
#   'response to extracellular stimulus',
#   'GO:0009991',
#   ['P76344']),
#  (0.5974396317990945,
#   'cellular response to DNA damage stimulus',
#   'GO:0006974',
#   ['P0A7G2', 'P0A910', 'P06996']),
#  (0.62552773966456,
#   'protein-containing complex subunit organization',
#   'GO:0043933',
#   ['P62399', 'P02931']),
#  (0.6457068685834104, 'amino acid transport', 'GO:0006865', ['P0AER8']),
#  (0.6494080555344723,
#   'cellular response to stimulus',
#   'GO:0051716',
#   ['P0A7G2', 'P0A910', 'P06996', 'P76344', 'P77330']),
#  (0.6541775452822667,
#   'cell wall organization or biogenesis',
#   'GO:0071554',
#   ['P0A908']),
#  (0.6583386609975694,
#   'cellular response to chemical stimulus',
#   'GO:0070887',
#   ['P77330']),
#  (0.6745013299914165,
#   'negative regulation of transcription, DNA-templated',
#   'GO:0045892',
#   ['P0ACF8']),
#  (0.6745013299914165,
#   'negative regulation of nucleic acid-templated transcription',
#   'GO:1903507',
#   ['P0ACF8']),
#  (0.6745013299914165,
#   'negative regulation of RNA biosynthetic process',
#   'GO:1902679',
#   ['P0ACF8']),
#  (0.6823012092847723, 'ncRNA processing', 'GO:0034470', ['P0A7G2']),
#  (0.6899191146730725,
#   'negative regulation of RNA metabolic process',
#   'GO:0051253',
#   ['P0ACF8']),
#  (0.6973591764208471,
#   'negative regulation of nucleobase-containing compound metabolic process',
#   'GO:0045934',
#   ['P0ACF8']),
#  (0.7254204436285208, 'RNA processing', 'GO:0006396', ['P0A7G2']),
#  (0.735276643669122, 'carboxylic acid transport', 'GO:0046942', ['P0AER8']),
#  (0.7384848861140099, 'organic acid transport', 'GO:0015849', ['P0AER8']),
#  (0.7447882762311232,
#   'cellular protein modification process',
#   'GO:0006464',
#   ['P0A6K3', 'P0A6K3']),
#  (0.7447882762311232,
#   'alpha-amino acid biosynthetic process',
#   'GO:1901607',
#   ['P0A9L8']),
#  (0.7447882762311232,
#   'protein modification process',
#   'GO:0036211',
#   ['P0A6K3', 'P0A6K3']),
#  (0.7685560044554453,
#   'negative regulation of cellular macromolecule biosynthetic process',
#   'GO:2000113',
#   ['P0ACF8']),
#  (0.7685560044554453,
#   'negative regulation of macromolecule biosynthetic process',
#   'GO:0010558',
#   ['P0ACF8']),
#  (0.771371069490011,
#   'negative regulation of cellular biosynthetic process',
#   'GO:0031327',
#   ['P0ACF8']),
#  (0.771371069490011,
#   'negative regulation of biosynthetic process',
#   'GO:0009890',
#   ['P0ACF8']),
#  (0.7769016072364338, 'ncRNA metabolic process', 'GO:0034660', ['P0A7G2']),
#  (0.782301891668594,
#   'negative regulation of nitrogen compound metabolic process',
#   'GO:0051172',
#   ['P0ACF8']),
#  (0.7901646035632907,
#   'negative regulation of cellular metabolic process',
#   'GO:0031324',
#   ['P0ACF8']),
#  (0.7901646035632907,
#   'cellular amino acid biosynthetic process',
#   'GO:0008652',
#   ['P0A9L8']),
#  (0.7952521665513705,
#   'negative regulation of gene expression',
#   'GO:0010629',
#   ['P0ACF8']),
#  (0.8276526456414053,
#   'negative regulation of macromolecule metabolic process',
#   'GO:0010605',
#   ['P0ACF8']),
#  (0.8318533126989853,
#   'negative regulation of metabolic process',
#   'GO:0009892',
#   ['P0ACF8']),
#  (0.8495555044384341,
#   'negative regulation of cellular process',
#   'GO:0048523',
#   ['P0ACF8', 'P0ACF8']),
#  (0.8699008053499142,
#   'gene expression',
#   'GO:0010467',
#   ['P0A6K3', 'P0A7K2', 'P62399', 'P0ACF8', 'P0ACF8', 'P0A7G2']),
#  (0.8775911812619056,
#   'response to stress',
#   'GO:0006950',
#   ['P0A7G2', 'P0A910', 'P06996', 'P76344', 'P0A7G2']),
#  (0.8897422606808973,
#   'negative regulation of biological process',
#   'GO:0048519',
#   ['P0ACF8', 'P0ACF8']),
#  (0.8977066118903376,
#   'alpha-amino acid metabolic process',
#   'GO:1901605',
#   ['P0A9L8']),
#  (0.9039134790887923,
#   'carboxylic acid biosynthetic process',
#   'GO:0046394',
#   ['P0A9L8']),
#  (0.9039134790887923,
#   'organic acid biosynthetic process',
#   'GO:0016053',
#   ['P0A9L8']),
#  (0.9145677726513259,
#   'biological regulation',
#   'GO:0065007',
#   ['P05825',
#    'P05825',
#    'P13036',
#    'P06971',
#    'P75780',
#    'P0ACF8',
#    'P0ACF8',
#    'P0ACF8']),
#  (0.922025198416566,
#   'cellular macromolecule biosynthetic process',
#   'GO:0034645',
#   ['P0A6K3', 'P0A7K2', 'P62399', 'P0ACF8', 'P0ACF8', 'P0A908']),
#  (0.9252299988061019,
#   'macromolecule biosynthetic process',
#   'GO:0009059',
#   ['P0A6K3', 'P0A7K2', 'P62399', 'P0ACF8', 'P0ACF8', 'P0A908']),
#  (0.9339578419572699,
#   'organonitrogen compound metabolic process',
#   'GO:1901564',
#   ['P0A6K3',
#    'P0A6K3',
#    'P0A6K3',
#    'P0A7K2',
#    'P62399',
#    'P0ACF8',
#    'P09169',
#    'P0A9L8',
#    'P0A908']),
#  (0.9502059905415471,
#   'cellular amino acid metabolic process',
#   'GO:0006520',
#   ['P0A9L8']),
#  (0.9502059905415471,
#   'carbohydrate derivative biosynthetic process',
#   'GO:1901137',
#   ['P0A908']),
#  (0.9652201934793012,
#   'regulation of transcription, DNA-templated',
#   'GO:0006355',
#   ['P0ACF8']),
#  (0.9652201934793012,
#   'regulation of RNA biosynthetic process',
#   'GO:2001141',
#   ['P0ACF8']),
#  (0.9652201934793012,
#   'regulation of nucleic acid-templated transcription',
#   'GO:1903506',
#   ['P0ACF8']),
#  (0.969822418323175,
#   'regulation of RNA metabolic process',
#   'GO:0051252',
#   ['P0ACF8']),
#  (0.9731420420190136,
#   'regulation of nucleobase-containing compound metabolic process',
#   'GO:0019219',
#   ['P0ACF8']),
#  (0.9754756205436979,
#   'small molecule biosynthetic process',
#   'GO:0044283',
#   ['P0A9L8']),
#  (0.9789499735552468,
#   'cellular nitrogen compound biosynthetic process',
#   'GO:0044271',
#   ['P0A6K3', 'P0A7K2', 'P62399', 'P0ACF8', 'P0ACF8']),
#  (0.9823062837207126,
#   'regulation of cellular macromolecule biosynthetic process',
#   'GO:2000112',
#   ['P0ACF8', 'P0ACF8']),
#  (0.9825368816433381,
#   'transcription, DNA-templated',
#   'GO:0006351',
#   ['P0ACF8']),
#  (0.9825368816433381,
#   'nucleic acid-templated transcription',
#   'GO:0097659',
#   ['P0ACF8']),
#  (0.9825368816433381,
#   'regulation of macromolecule biosynthetic process',
#   'GO:0010556',
#   ['P0ACF8', 'P0ACF8']),
#  (0.9832112685344486,
#   'regulation of cellular biosynthetic process',
#   'GO:0031326',
#   ['P0ACF8', 'P0ACF8']),
#  (0.9836467095595566,
#   'regulation of biosynthetic process',
#   'GO:0009889',
#   ['P0ACF8', 'P0ACF8']),
#  (0.9846877925293095, 'RNA biosynthetic process', 'GO:0032774', ['P0ACF8']),
#  (0.9857412288443415,
#   'RNA metabolic process',
#   'GO:0016070',
#   ['P0ACF8', 'P0A7G2']),
#  (0.9858521705657889,
#   'regulation of gene expression',
#   'GO:0010468',
#   ['P0ACF8', 'P0ACF8']),
#  (0.9874388392869154,
#   'regulation of nitrogen compound metabolic process',
#   'GO:0051171',
#   ['P0ACF8', 'P0ACF8']),
#  (0.9888518421734437,
#   'regulation of primary metabolic process',
#   'GO:0080090',
#   ['P0ACF8', 'P0ACF8']),
#  (0.9889989469664474,
#   'regulation of cellular metabolic process',
#   'GO:0031323',
#   ['P0ACF8', 'P0ACF8']),
#  (0.9901097163809656,
#   'carbohydrate derivative metabolic process',
#   'GO:1901135',
#   ['P0A908']),
#  (0.9907476910536777,
#   'regulation of macromolecule metabolic process',
#   'GO:0060255',
#   ['P0ACF8', 'P0ACF8']),
#  (0.9926311687933163,
#   'regulation of metabolic process',
#   'GO:0019222',
#   ['P0ACF8', 'P0ACF8']),
#  (0.9957048963641446,
#   'heterocycle biosynthetic process',
#   'GO:0018130',
#   ['P0ACF8', 'P0A9L8']),
#  (0.9962797573848915,
#   'macromolecule metabolic process',
#   'GO:0043170',
#   ['P0A6K3',
#    'P0A6K3',
#    'P0A6K3',
#    'P0A7K2',
#    'P62399',
#    'P0ACF8',
#    'P09169',
#    'P0ACF8',
#    'P0A908',
#    'P0A7G2']),
#  (0.9964034818927825,
#   'organic cyclic compound biosynthetic process',
#   'GO:1901362',
#   ['P0ACF8', 'P0A9L8']),
#  (0.9970940637796096,
#   'organic substance biosynthetic process',
#   'GO:1901576',
#   ['P0A6K3', 'P0A7K2', 'P62399', 'P0ACF8', 'P0ACF8', 'P0A908', 'P0A9L8']),
#  (0.9971277877363143,
#   'cellular biosynthetic process',
#   'GO:0044249',
#   ['P0A6K3', 'P0A7K2', 'P62399', 'P0ACF8', 'P0ACF8', 'P0A908', 'P0A9L8']),
#  (0.9974538622873086,
#   'carboxylic acid metabolic process',
#   'GO:0019752',
#   ['P0A9L8']),
#  (0.9977831169852954,
#   'nucleobase-containing compound biosynthetic process',
#   'GO:0034654',
#   ['P0ACF8']),
#  (0.9979623581700905,
#   'biosynthetic process',
#   'GO:0009058',
#   ['P0A6K3', 'P0A7K2', 'P62399', 'P0ACF8', 'P0ACF8', 'P0A908', 'P0A9L8']),
#  (0.9983401310344165,
#   'cellular macromolecule metabolic process',
#   'GO:0044260',
#   ['P0A6K3',
#    'P0A6K3',
#    'P0A6K3',
#    'P0A7K2',
#    'P62399',
#    'P0ACF8',
#    'P0ACF8',
#    'P0A908']),
#  (0.9984354017573132,
#   'organic acid metabolic process',
#   'GO:0006082',
#   ['P0A9L8']),
#  (0.9985207021591869,
#   'regulation of cellular process',
#   'GO:0050794',
#   ['P0ACF8', 'P0ACF8', 'P0ACF8']),
#  (0.9989494321726179,
#   'nucleic acid metabolic process',
#   'GO:0090304',
#   ['P0ACF8', 'P0A7G2']),
#  (0.9991595097232419,
#   'regulation of biological process',
#   'GO:0050789',
#   ['P0ACF8', 'P0ACF8', 'P0ACF8']),
#  (0.9993775341499005,
#   'aromatic compound biosynthetic process',
#   'GO:0019438',
#   ['P0ACF8']),
#  (0.9996795267234329,
#   'cellular nitrogen compound metabolic process',
#   'GO:0034641',
#   ['P0A6K3', 'P0A7K2', 'P62399', 'P0ACF8', 'P0ACF8', 'P0A7G2']),
#  (0.9998923683724174,
#   'nitrogen compound metabolic process',
#   'GO:0006807',
#   ['P0A6K3',
#    'P0A6K3',
#    'P0A6K3',
#    'P0A7K2',
#    'P62399',
#    'P0ACF8',
#    'P09169',
#    'P0A9L8',
#    'P0A908',
#    'P0ACF8',
#    'P0A7G2']),
#  (0.9999201489103801,
#   'heterocycle metabolic process',
#   'GO:0046483',
#   ['P0ACF8', 'P0A7G2', 'P0A9L8']),
#  (0.9999458629497031,
#   'nucleobase-containing compound metabolic process',
#   'GO:0006139',
#   ['P0ACF8', 'P0A7G2']),
#  (0.9999573460425063,
#   'organic cyclic compound metabolic process',
#   'GO:1901360',
#   ['P0ACF8', 'P0A7G2', 'P0A9L8']),
#  (0.9999887695201162,
#   'small molecule metabolic process',
#   'GO:0044281',
#   ['P0A9L8']),
#  (0.9999926712384618,
#   'cellular aromatic compound metabolic process',
#   'GO:0006725',
#   ['P0ACF8', 'P0A7G2']),
#  (0.9999982369743188,
#   'cellular process',
#   'GO:0009987',
#   ['P77774',
#    'P0A940',
#    'P0A937',
#    'P62399',
#    'P02931',
#    'P77774',
#    'P0A940',
#    'P0A937',
#    'P76506',
#    'P0A6K3',
#    'P0A6K3',
#    'P0A6K3',
#    'P0A7K2',
#    'P62399',
#    'P0ACF8',
#    'P0ACF8',
#    'P0A908',
#    'P0A9L8',
#    'P0A7G2',
#    'P05825',
#    'P05825',
#    'P0ACF8',
#    'P0A910',
#    'P0A7G2',
#    'P0A910',
#    'P06996',
#    'P76344',
#    'P77330']),
#  (0.9999986827634597,
#   'primary metabolic process',
#   'GO:0044238',
#   ['P0A6K3',
#    'P0A6K3',
#    'P0A6K3',
#    'P0A7K2',
#    'P62399',
#    'P0ACF8',
#    'P09169',
#    'P0ACF8',
#    'P0A7G2',
#    'P0A9L8']),
#  (0.9999999851484336,
#   'organic substance metabolic process',
#   'GO:0071704',
#   ['P0A6K3',
#    'P0A6K3',
#    'P0A6K3',
#    'P0A7K2',
#    'P62399',
#    'P0ACF8',
#    'P09169',
#    'P0ACF8',
#    'P0A908',
#    'P0A7G2',
#    'P0A9L8']),
#  (0.9999999938841001,
#   'cellular metabolic process',
#   'GO:0044237',
#   ['P0A6K3',
#    'P0A6K3',
#    'P0A6K3',
#    'P0A7K2',
#    'P62399',
#    'P0ACF8',
#    'P0ACF8',
#    'P0A908',
#    'P0A9L8',
#    'P0A7G2']),
#  (0.9999999995641846,
#   'metabolic process',
#   'GO:0008152',
#   ['P0A6K3',
#    'P0A6K3',
#    'P0A6K3',
#    'P0A7K2',
#    'P62399',
#    'P0ACF8',
#    'P09169',
#    'P0ACF8',
#    'P0A908',
#    'P0A7G2',
#    'P0A9L8']),
#  (1.0,
#   'biological_process',
#   'GO:0008150',
#   ['P77774',
#    'P0A940',
#    'P0A937',
#    'P62399',
#    'P02931',
#    'P77774',
#    'P0A940',
#    'P0A937',
#    'P76506',
#    'P0A6K3',
#    'P0A6K3',
#    'P0A6K3',
#    'P0A7K2',
#    'P62399',
#    'P0ACF8',
#    'P0ACF8',
#    'P0A908',
#    'P0A9L8',
#    'P0A7G2',
#    'P05825',
#    'P05825',
#    'P0ACF8',
#    'P0A910',
#    'P0A7G2',
#    'P0A910',
#    'P06996',
#    'P76344',
#    'P77330',
#    'P06996',
#    'P05825',
#    'P75780',
#    'P0AER8',
#    'P0A927',
#    'P06129',
#    'P02930',
#    'P0A927',
#    'P0A910',
#    'P13036',
#    'P13036',
#    'P06971',
#    'P75780',
#    'P0A910',
#    'P06129',
#    'P02930',
#    'P02931',
#    'P02931',
#    'P02930',
#    'P0A940',
#    'P09169',
#    'P13036',
#    'P06971',
#    'P75780',
#    'P0ADB7',
#    'P0A937',
#    'P02930',
#    'P76344',
#    'P0AB40',
#    'P02930',
#    'P0A7G2',
#    'P0A910',
#    'P0A927',
#    'P0A910'])]

# %%
class Rich_GO_ORA() :
    def __init__(self,bio_proc):
        self.bio_proc = bio_proc
    def _repr_html_(self) :
        htmlString = "<table><thead><tr><td>P-Value</td><td>Activity</td><td>GO_ID</td><td>List_Value</td><td>GO_Term</td></tr></thead>"
        for i in self.bio_proc :
            htmlString += f"<tbody><tr><td>{i[0]}</td><td>{i[1]}</td><td>{i[2]}</td><td>{i[3]}</td><td><a href = http://amigo.geneontology.org/amigo/term/{i[2]}>{i[2]}</a></td></tr></tbody>"
        htmlString += "</table>"
        return htmlString
        

Rich_GO_ORA(bp_sup5)
# Out:
# <table><thead><tr><td>P-Value</td><td>Activity</td><td>GO_ID</td><td>List_Value</td><td>GO_Term</td></tr></thead><tbody><tr><td>1.277774972034038e-06</td><td>siderophore transport</td><td>GO:0015891</td><td>['P13036', 'P06971', 'P75780', 'P02930', 'P05825']</td><td><a href = http://amigo.geneontology.org/amigo/term/GO:0015891>GO:0015891</a></td></tr></tbody><tbody><tr><td>6.023913047836394e-06</td><td>iron coordination entity transport</td><td>GO:1901678</td><td>['P05825', 'P05825', 'P13036', 'P06971', 'P75780', 'P02930']</td><td><a href = http://amigo.geneontology.org/amigo/term/GO:1901678>GO:1901678</a></td></tr></tbody><tbody><tr><td>5.532051927766727e-05</td><td>iron ion transport</td><td>GO:0006826</td><td>['P13036', 'P05825', 'P05825', 'P13036', 'P06971', 'P75780', 'P02930']</td><td><a href = http://amigo.geneontology.org/amigo/term/GO:0006826>GO:0006826</a></td></tr></tbody><tbody><tr><td>0.0001270732486959893</td><td>ion transport</td><td>GO:0006811</td><td>['P0A927', 'P0A910', 'P13036', 'P05825', 'P05825', 'P13036', 'P06971', 'P75780', 'P02930', 'P0AER8', 'P06996', 'P76506', 'P0A910', 'P06129', 'P02930', 'P02931']</td><td><a href = http://amigo.geneontology.org/amigo/term/GO:0006811>GO:0006811</a></td></tr></tbody><tbody><tr><td>0.00023017691092962867</td><td>membrane organization</td><td>GO:0061024</td><td>['P77774', 'P0A940', 'P0A937', 'P77774', 'P0A940', 'P0A937', 'P76506']</td><td><a href = http://amigo.geneontology.org/amigo/term/GO:0061024>GO:0061024</a></td></tr></tbody><tbody><tr><td>0.00038932504762125263</td><td>protein insertion into membrane</td><td>GO:0051205</td><td>['P77774', 'P0A940', 'P0A937']</td><td><a href = http://amigo.geneontology.org/amigo/term/GO:0051205>GO:0051205</a></td></tr></tbody><tbody><tr><td>0.0006094525728954648</td><td>Gram-negative-bacterium-type cell outer membrane assembly</td><td>GO:0043165</td><td>['P77774', 'P0A940', 'P0A937']</td><td><a href = http://amigo.geneontology.org/amigo/term/GO:0043165>GO:0043165</a></td></tr></tbody><tbody><tr><td>0.0006094525728954648</td><td>membrane assembly</td><td>GO:0071709</td><td>['P77774', 'P0A940', 'P0A937']</td><td><a href = http://amigo.geneontology.org/amigo/term/GO:0071709>GO:0071709</a></td></tr></tbody><tbody><tr><td>0.0007440622520732061</td><td>establishment of protein localization to membrane</td><td>GO:0090150</td><td>['P77774', 'P0A940', 'P0A937']</td><td><a href = http://amigo.geneontology.org/amigo/term/GO:0090150>GO:0090150</a></td></tr></tbody><tbody><tr><td>0.0009756392518373065</td><td>iron ion homeostasis</td><td>GO:0055072</td><td>['P13036', 'P06971', 'P75780', 'P05825', 'P05825']</td><td><a href = http://amigo.geneontology.org/amigo/term/GO:0055072>GO:0055072</a></td></tr></tbody><tbody><tr><td>0.0013025572322994698</td><td>phospholipid transport</td><td>GO:0015914</td><td>['P06996', 'P76506']</td><td><a href = http://amigo.geneontology.org/amigo/term/GO:0015914>GO:0015914</a></td></tr></tbody><tbody><tr><td>0.001825589084162934</td><td>transition metal ion homeostasis</td><td>GO:0055076</td><td>['P05825', 'P05825', 'P13036', 'P06971', 'P75780']</td><td><a href = http://amigo.geneontology.org/amigo/term/GO:0055076>GO:0055076</a></td></tr></tbody><tbody><tr><td>0.0019788009948913735</td><td>metal ion homeostasis</td><td>GO:0055065</td><td>['P05825', 'P05825', 'P13036', 'P06971', 'P75780']</td><td><a href = http://amigo.geneontology.org/amigo/term/GO:0055065>GO:0055065</a></td></tr></tbody><tbody><tr><td>0.002135325180678235</td><td>establishment of localization</td><td>GO:0051234</td><td>['P77774', 'P0A940', 'P0A937', 'P05825', 'P75780', 'P0AER8', 'P0A927', 'P06129', 'P02930', 'P05825', 'P06996', 'P76506', 'P0A927', 'P0A910', 'P13036', 'P05825', 'P13036', 'P06971', 'P75780', 'P0A910', 'P06129', 'P02930', 'P02931', 'P02931', 'P02930']</td><td><a href = http://amigo.geneontology.org/amigo/term/GO:0051234>GO:0051234</a></td></tr></tbody><tbody><tr><td>0.0024917150479736015</td><td>cellular localization</td><td>GO:0051641</t ...

# %% [markdown]
# ## Une deuxième application: volcano plot améliorés
# ###### PANDAS
# En choisissant comme seuil la valeur `alpha` du TP précédent, veuillez extraires les identifiants uniprot des protéines sur-abondantes (rappel les valeurs d'abondance sont celles de la colonne `Log2 Corrected Abundance Ratio`).
#
# Vous devrez avoir dans des listes distinctes:
# * identifiants uniprot
# * `Log2 Corrected Abundance Ratio`
# * `LOG10 Adj.P-val'`
#
# ###### Représentation graphiques
# * Pour la catégorie de termes GO (biological_process / molecular_function /cellular_component) de votre choix
#     * Générer une grille de 4 graphiques
#     * Dans chaque graphique colorez dans une couleur différentes les protéines porteuses de 4 termes de GO que vous estimez les plus pertinents
#     * Donnez le nom de la catégorie générale à la grille
#     * Donnez le nom du terme GO représenté dans chaque graphique avec une couleur de titre cohérente.

# %%
#Seuil alpha récupéré du TP précédent
alpha = 0.096
#Création des listes
list_alpha_id=list(data_frame[(data_frame["Log2 Corrected Abundance Ratio"]>alpha)]["Accession"])
list_alpha_log2=list(data_frame[(data_frame["Log2 Corrected Abundance Ratio"]>alpha)]["Log2 Corrected Abundance Ratio"])
list_alpha_log10=list(data_frame[(data_frame["Log2 Corrected Abundance Ratio"]>alpha)]["LOG10 Adj.P-val"])
list_go_alpha=o.biological_process(list_alpha_id)
# Out:
# Evaluated 240 / 246 Pathways, based on 31 proteins

# %%
Rich_GO_ORA(list_go_alpha)
# Out:
# <table><thead><tr><td>P-Value</td><td>Activity</td><td>GO_ID</td><td>List_Value</td><td>GO_Term</td></tr></thead><tbody><tr><td>5.132796457470556e-07</td><td>siderophore transport</td><td>GO:0015891</td><td>['P13036', 'P06971', 'P75780', 'P02930', 'P05825']</td><td><a href = http://amigo.geneontology.org/amigo/term/GO:0015891>GO:0015891</a></td></tr></tbody><tbody><tr><td>2.4428321153130882e-06</td><td>iron coordination entity transport</td><td>GO:1901678</td><td>['P05825', 'P05825', 'P13036', 'P06971', 'P75780', 'P02930']</td><td><a href = http://amigo.geneontology.org/amigo/term/GO:1901678>GO:1901678</a></td></tr></tbody><tbody><tr><td>1.702919516842175e-05</td><td>ion transport</td><td>GO:0006811</td><td>['P0A927', 'P0A910', 'P13036', 'P05825', 'P05825', 'P13036', 'P06971', 'P75780', 'P02930', 'P0AER8', 'P06996', 'P76506', 'P0A910', 'P06129', 'P02930', 'P02931']</td><td><a href = http://amigo.geneontology.org/amigo/term/GO:0006811>GO:0006811</a></td></tr></tbody><tbody><tr><td>2.2898132422704963e-05</td><td>iron ion transport</td><td>GO:0006826</td><td>['P13036', 'P05825', 'P05825', 'P13036', 'P06971', 'P75780', 'P02930']</td><td><a href = http://amigo.geneontology.org/amigo/term/GO:0006826>GO:0006826</a></td></tr></tbody><tbody><tr><td>0.0004937509848459438</td><td>iron ion homeostasis</td><td>GO:0055072</td><td>['P13036', 'P06971', 'P75780', 'P05825', 'P05825']</td><td><a href = http://amigo.geneontology.org/amigo/term/GO:0055072>GO:0055072</a></td></tr></tbody><tbody><tr><td>0.0009163623570639523</td><td>phospholipid transport</td><td>GO:0015914</td><td>['P06996', 'P76506']</td><td><a href = http://amigo.geneontology.org/amigo/term/GO:0015914>GO:0015914</a></td></tr></tbody><tbody><tr><td>0.0009336084540530498</td><td>transition metal ion homeostasis</td><td>GO:0055076</td><td>['P05825', 'P05825', 'P13036', 'P06971', 'P75780']</td><td><a href = http://amigo.geneontology.org/amigo/term/GO:0055076>GO:0055076</a></td></tr></tbody><tbody><tr><td>0.0010134716686980576</td><td>metal ion homeostasis</td><td>GO:0055065</td><td>['P05825', 'P05825', 'P13036', 'P06971', 'P75780']</td><td><a href = http://amigo.geneontology.org/amigo/term/GO:0055065>GO:0055065</a></td></tr></tbody><tbody><tr><td>0.0017056788235080562</td><td>cofactor transport</td><td>GO:0051181</td><td>['P02930', 'P05825', 'P06129']</td><td><a href = http://amigo.geneontology.org/amigo/term/GO:0051181>GO:0051181</a></td></tr></tbody><tbody><tr><td>0.0019618936312202793</td><td>cation homeostasis</td><td>GO:0055080</td><td>['P05825', 'P05825', 'P13036', 'P06971', 'P75780']</td><td><a href = http://amigo.geneontology.org/amigo/term/GO:0055080>GO:0055080</a></td></tr></tbody><tbody><tr><td>0.002095528535218382</td><td>ion homeostasis</td><td>GO:0050801</td><td>['P05825', 'P05825', 'P13036', 'P06971', 'P75780']</td><td><a href = http://amigo.geneontology.org/amigo/term/GO:0050801>GO:0050801</a></td></tr></tbody><tbody><tr><td>0.0025341882354035015</td><td>chemical homeostasis</td><td>GO:0048878</td><td>['P05825', 'P05825', 'P13036', 'P06971', 'P75780']</td><td><a href = http://amigo.geneontology.org/amigo/term/GO:0048878>GO:0048878</a></td></tr></tbody><tbody><tr><td>0.0028810206241173266</td><td>establishment of localization</td><td>GO:0051234</td><td>['P77774', 'P0A940', 'P0A937', 'P05825', 'P75780', 'P0AER8', 'P0A927', 'P06129', 'P02930', 'P05825', 'P06996', 'P76506', 'P0A927', 'P0A910', 'P13036', 'P05825', 'P13036', 'P06971', 'P75780', 'P0A910', 'P06129', 'P02930', 'P02931', 'P02931', 'P02930']</td><td><a href = http://amigo.geneontology.org/amigo/term/GO:0051234>GO:0051234</a></td></tr></tbody><tbody><tr><td>0.0032189758623649796</td><td>enterobactin transport</td><td>GO:0042930</td><td>['P02930', 'P05825']</td><td><a href = http://amigo.geneontology.org/amigo/term/GO:0042930>GO:0042930</a></td></tr></tbody><tbody><tr><td>0.004006252441167605</td><td>drug transport</td><td>GO:0015893</td><td>['P02931', 'P0AER8', 'P06129', 'P02930']</td><td><a href = http://amigo.g ...

# %%
#Représentation graphiques
fig1, ((ax1, ax2), (ax3, ax4)) = plt.subplots(figsize=(10,6), ncols=2, nrows=2, dpi = 226)
function_col = [ "red" if x>0.106309 and y>1.014018 else "black" for x,y in zip(list_alpha_log2,list_alpha_log10)]
ax1.scatter(list_alpha_log2,list_alpha_log10,c=function_col)
ax2.scatter(list_alpha_log2,list_alpha_log10,c=function_col)f
ax3.scatter(list_alpha_log2,list_alpha_log10,c=function_col)
ax4.scatter(list_alpha_log2,list_alpha_log10,c=function_col)
fig1.suptitle("protein with the best value",color="red")
# Out:
# Text(0.5, 0.98, 'protein with the best value')

# %%
chr()
# Out:
# 'a'

# %%
import random
nb_10,lettre_10=[i for i in range(10)],[chr(i) for i in range(65,97) ]
random.shuffle(nb_10)
random.shuffle(lettre_10)
dic={i : j for i,j in zip(nb_10,lettre_10)}
dic
# Out:
# {8: 'Z',
#  2: 'M',
#  3: 'I',
#  5: '`',
#  1: 'D',
#  0: 'W',
#  7: ']',
#  9: '[',
#  4: 'B',
#  6: 'T'}

# %%
list_go_alpha[1]
# Out:
# (2.4428321153130882e-06,
#  'iron coordination entity transport',
#  'GO:1901678',
#  ['P05825', 'P05825', 'P13036', 'P06971', 'P75780', 'P02930'])

# %%
Rich_GO_ORA(sorted(list_go_alpha,key=lambda x : x[0] ))
# Out:
# <table><thead><tr><td>P-Value</td><td>Activity</td><td>GO_ID</td><td>List_Value</td><td>GO_Term</td></tr></thead><tbody><tr><td>5.132796457470556e-07</td><td>siderophore transport</td><td>GO:0015891</td><td>['P13036', 'P06971', 'P75780', 'P02930', 'P05825']</td><td><a href = http://amigo.geneontology.org/amigo/term/GO:0015891>GO:0015891</a></td></tr></tbody><tbody><tr><td>2.4428321153130882e-06</td><td>iron coordination entity transport</td><td>GO:1901678</td><td>['P05825', 'P05825', 'P13036', 'P06971', 'P75780', 'P02930']</td><td><a href = http://amigo.geneontology.org/amigo/term/GO:1901678>GO:1901678</a></td></tr></tbody><tbody><tr><td>1.702919516842175e-05</td><td>ion transport</td><td>GO:0006811</td><td>['P0A927', 'P0A910', 'P13036', 'P05825', 'P05825', 'P13036', 'P06971', 'P75780', 'P02930', 'P0AER8', 'P06996', 'P76506', 'P0A910', 'P06129', 'P02930', 'P02931']</td><td><a href = http://amigo.geneontology.org/amigo/term/GO:0006811>GO:0006811</a></td></tr></tbody><tbody><tr><td>2.2898132422704963e-05</td><td>iron ion transport</td><td>GO:0006826</td><td>['P13036', 'P05825', 'P05825', 'P13036', 'P06971', 'P75780', 'P02930']</td><td><a href = http://amigo.geneontology.org/amigo/term/GO:0006826>GO:0006826</a></td></tr></tbody><tbody><tr><td>0.0004937509848459438</td><td>iron ion homeostasis</td><td>GO:0055072</td><td>['P13036', 'P06971', 'P75780', 'P05825', 'P05825']</td><td><a href = http://amigo.geneontology.org/amigo/term/GO:0055072>GO:0055072</a></td></tr></tbody><tbody><tr><td>0.0009163623570639523</td><td>phospholipid transport</td><td>GO:0015914</td><td>['P06996', 'P76506']</td><td><a href = http://amigo.geneontology.org/amigo/term/GO:0015914>GO:0015914</a></td></tr></tbody><tbody><tr><td>0.0009336084540530498</td><td>transition metal ion homeostasis</td><td>GO:0055076</td><td>['P05825', 'P05825', 'P13036', 'P06971', 'P75780']</td><td><a href = http://amigo.geneontology.org/amigo/term/GO:0055076>GO:0055076</a></td></tr></tbody><tbody><tr><td>0.0010134716686980576</td><td>metal ion homeostasis</td><td>GO:0055065</td><td>['P05825', 'P05825', 'P13036', 'P06971', 'P75780']</td><td><a href = http://amigo.geneontology.org/amigo/term/GO:0055065>GO:0055065</a></td></tr></tbody><tbody><tr><td>0.0017056788235080562</td><td>cofactor transport</td><td>GO:0051181</td><td>['P02930', 'P05825', 'P06129']</td><td><a href = http://amigo.geneontology.org/amigo/term/GO:0051181>GO:0051181</a></td></tr></tbody><tbody><tr><td>0.0019618936312202793</td><td>cation homeostasis</td><td>GO:0055080</td><td>['P05825', 'P05825', 'P13036', 'P06971', 'P75780']</td><td><a href = http://amigo.geneontology.org/amigo/term/GO:0055080>GO:0055080</a></td></tr></tbody><tbody><tr><td>0.002095528535218382</td><td>ion homeostasis</td><td>GO:0050801</td><td>['P05825', 'P05825', 'P13036', 'P06971', 'P75780']</td><td><a href = http://amigo.geneontology.org/amigo/term/GO:0050801>GO:0050801</a></td></tr></tbody><tbody><tr><td>0.0025341882354035015</td><td>chemical homeostasis</td><td>GO:0048878</td><td>['P05825', 'P05825', 'P13036', 'P06971', 'P75780']</td><td><a href = http://amigo.geneontology.org/amigo/term/GO:0048878>GO:0048878</a></td></tr></tbody><tbody><tr><td>0.0028810206241173266</td><td>establishment of localization</td><td>GO:0051234</td><td>['P77774', 'P0A940', 'P0A937', 'P05825', 'P75780', 'P0AER8', 'P0A927', 'P06129', 'P02930', 'P05825', 'P06996', 'P76506', 'P0A927', 'P0A910', 'P13036', 'P05825', 'P13036', 'P06971', 'P75780', 'P0A910', 'P06129', 'P02930', 'P02931', 'P02931', 'P02930']</td><td><a href = http://amigo.geneontology.org/amigo/term/GO:0051234>GO:0051234</a></td></tr></tbody><tbody><tr><td>0.0032189758623649796</td><td>enterobactin transport</td><td>GO:0042930</td><td>['P02930', 'P05825']</td><td><a href = http://amigo.geneontology.org/amigo/term/GO:0042930>GO:0042930</a></td></tr></tbody><tbody><tr><td>0.004006252441167605</td><td>drug transport</td><td>GO:0015893</td><td>['P02931', 'P0AER8', 'P06129', 'P02930']</td><td><a href = http://amigo.g ...

# %%
biggest_pvalue=sorted(list_go_alpha,key=lambda x : x[0] )[0]

# %%
list_id_b=biggest_pvalue[3]

# %%
data_frame[(data_frame["Log2 Corrected Abundance Ratio"]>0) & (data_frame["LOG10 Adj.P-val"]>4)]

# %%
log2=[]
log10=[]
for i in list_id_b :
    log2.append(data_frame[(data_frame["Accession"]==i)]["Log2 Corrected Abundance Ratio"])
    log10.append(data_frame[(data_frame["Accession"]==i)]["LOG10 Adj.P-val"])

# %%
log2
log10
# Out:
# [1984    4.571899
#  Name: LOG10 Adj.P-val, dtype: float64,
#  1992    5.156463
#  Name: LOG10 Adj.P-val, dtype: float64,
#  2001    1.014018
#  Name: LOG10 Adj.P-val, dtype: float64,
#  2016    1.873757
#  Name: LOG10 Adj.P-val, dtype: float64,
#  1962    1.816916
#  Name: LOG10 Adj.P-val, dtype: float64]
